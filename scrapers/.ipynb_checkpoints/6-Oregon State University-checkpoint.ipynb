# %% [markdown]
# ## Oregon State University Crawler

# %% [markdown]
# Imports.

# %%
import pandas as pd
import numpy as np
import re
import urllib.request #handles urls
import urllib.parse 
import linkGrabber #extracts urls
import json #encodes/decodes json 
import csv 
import requests #downloads a webpage to scrape
from bs4 import BeautifulSoup, NavigableString, Tag #beautifulsoup pulls data from HTML
import nltk #NLP tasks
from nltk import word_tokenize
from nltk.stem import PorterStemmer #removes word endings
stemmer = PorterStemmer()

# %% [markdown]
# Keyword preprocessing and url list of relevant catalog years; 2019-20 and 2018-19. Also a list of departments.

# %%
#keyword preprocessing
def preprocess(keyword):
    keyword = keyword.lower() #lowercase
    keyword = word_tokenize(keyword) #tokenize
    for word in keyword:
        keyword = stemmer.stem(word) #stem 
    return (keyword)

#course catalog URLs - 2 academic years 
urls = ['https://catalog.oregonstate.edu/courses/',
        'https://catalog.oregonstate.edu/archives/2018-2019/courses/']

#list of all the departments to search through 
departments = ['als/','actg/','ahe/','aae/','as/','aed/',
              'agri/','ag/','asl/','ams/','ans/','anth/',
              'aec/','aj/','arab/','art/','asn/','ats/',
              'bb/','bhs/','bee/','bds/','bioe/','bi/',
              'brr/','bot/','ba/','cbee/','che/','ch/',
              'chn/','cce/','ce/','cssa/','comm/','cs/',
              'cem/','coun/','css/','crop/','dsgn/','dhe/',
              'econ/','ed/','ece/','ese/','engr/','eng/',
              'ent/','eah/','enve/','ensc/','es/','film/',
              'fin/','fw/','fcsj/','fst/','fes/','fe/',
              'for/','fr/','gs/','geog/','gph/','geo/',
              'ger/','grad/','gd/','hhs/','herb/','hst/',
              'hsts/','hc/','hort/','hm/','hdfs/','hest/',
              'ie/','ib/','iepa/','iepg/','ieph/','ist/',
              'intl/','it/','jpn/','kin/','kor/','lead/',
              'la/','ls/','lib/','ling/','mgmt/','mfge/',
              'mrm/','mrkt/','mnr/','mpp/','mats/','mth/',
              'mime/','me/','mb/','ms/','mcb/','mus/','mup',
              'mued/','nr/','ns/','nmc/','nse/','nur/',
              'nutr/','oeas/','oc/','op/','pax/','phar/',
              'phl/','pac/','pt/','ph/','pbg/','ps/','psm/',
              'psy/','h/','ppol/','qs/','rng/','rel/','rob/',
              'rs/','rus/','sed/','ssci/','soc/','se/','soil/',
              'span/','st/','sus/','snr/','ta/','tral/','tox/',
              'tcs/','uexp/','vmb/','vmc/','wre/','wrp/',
              'wrs/','wgss/','wse/','wlc/','wr','z/']

# %% [markdown]
# Next, we'll want to import our keyword csv, split our keyword lists, and preprocess them. The way the csv is set up, we'll want to split the words that are indicated as technical (`T`) or normative (`N`) and that we've chosen to include (`Y`). You'll notice that preprocessing is useful for some of our words but not for others. Here, we've chosen to manually alter words that are not usefully preprocessed. In this case, it means replacing instances of words that are stemmed to end in i.
#
# [regex is a bitch here]

# %%
#import keywords
keywords = pd.read_csv("keywords.csv")
technical = keywords[(keywords['Technical/Normative']=='T') & (keywords['Include']=='Y')].Keyword
normative = keywords[(keywords['Technical/Normative']=='N') & (keywords['Include']=='Y')].Keyword
normative = [preprocess(i) for i in normative]
technical = [preprocess(i) for i in technical] 

#replace keywords of interest
normative = [w.replace('privaci', 'privac') for w in normative]
normative = [w.replace('democraci', 'democra') for w in normative]
normative = [w.replace('equiti', 'equit') for w in normative]
normative = [w.replace('histori', 'histor') for w in normative]
normative = [w.replace('justice', 'justic') for w in normative]
normative = [w.replace('liberti', 'libert') for w in normative]
normative = [w.replace('philosophi', 'philosoph') for w in normative]
normative = [w.replace('societi', 'societ') for w in normative]
normative = [w.replace('polici', 'polic') for w in normative]

technical = [w.replace('ai', '^ai') for w in technical]
technical = [w.replace('cs', '^cs') for w in technical]
technical = [w.replace('ict', '^ict') for w in technical]
technical = [w.replace('ml', '^ml') for w in technical]
technical = [w.replace('nlp', '^nlp') for w in technical]

print(normative)
print(technical)
# Out:
# ['account', 'critic', 'democra', 'discrimin', 'equal', 'equit', 'ethic', 'fair', 'femin', 'gender', 'govern', 'histor', 'inequ', 'justic', 'law', 'legal', 'libert', 'moral', 'norm', 'philosoph', 'polit', 'power', 'privac', 'race', 'religi', 'respons', 'right', 'secur', 'social', 'societ', 'surveil', 'transpar', 'valu', 'polic']
# ['^ai', 'algorithm', 'analyt', 'intellig', 'automat', 'code', 'comput', '^cs', 'cyber', 'data', 'digit', '^ict', 'inform', 'intelligen', 'internet', 'machin', '^ml', 'process', '^nlp', 'platform', 'program', 'robot', 'softwar', 'system', 'technolog']

# %% [markdown]
# The process behind extracting relevant courses works in two steps:
# 1. First, we want to find and extract all courses that contain any instance of a normative keyword.
# 2. Then, we want search within these courses to see if it also contains a technical keyword.
#
# We initialize a data frame with columns for all of the course items we want to extract. It probably makes the most sense to standardize these feature names across all university scripts so that they're easier to merge in the final compiled dataset for all universities. Our items of interest are:
# * The course title: `title`
# * The department and course number: `dept_num`
# * The course description: `description`
# * The number of credits for the course: `credits`
# * The course instructor: `instructor`
# * The link to the course syllabus (if applicable): `syllabus`
# * The university the course is extracted from: `university`
# * The term that the course is offered during (fall, spring, summer / year): `term`
# * The keyword that triggered the extraction (this is for auditing purposes): `keyword`

# %%
#init dfs
oregon = pd.DataFrame(columns=['title','dept_num','description','credits','instructor',
                                'syllabus','university','term','keyword'])
titles = []
dept_nums = []
descs = []
credit = []
profs = []
syllabi = []
uni = []
term = []     
keyword = []

# %% [markdown]
# The loop below executes part 1 of our extraction. It's long and kind of messy (sorry), so feel free to play around with the structure if you'd like. The key tasks here are to extract our items of interest based on our search queries and append them to our data frame.

# %%
#looping through each years catalog
for url in urls:
    #looping through all the departments pages to process individual course's information
    for dept in departments:
        page_link = url + dept
        page_response = requests.get(page_link)
        soup = BeautifulSoup(page_response.content, 'html.parser')
        courses = [p.get_text().split('\n') for p in soup.select(".courseblock")]
        for crs in courses:
            title = crs[1]
            for word in normative:
                if word in title.lower():
                    titles.append(title[title.find('.')+1:title.rfind('.')])
                    dept_nums.append(title[:title.find('.')])
                    descs.append(crs[2])
                    credit.append(title[title.find('(')+1:len(title)-1])
                    profs.append('Not Listed')
                    syllabi.append('Not Listed')
                    uni.append('Oregon State University')
                    if url == 'https://catalog.oregonstate.edu/courses/':
                        term.append('2019-20')
                    else:
                        term.append('2018-19')
                    keyword.append(word)
            
for a,b,c,d,e,f,g,h,i in zip(titles,dept_nums,descs,credit,profs,syllabi,uni,term,keyword):
    oregon = oregon.append({'title': a, 
                              'dept_num': b,
                              'description': c,
                              'credits': d,
                              'instructor': e,
                              'syllabus': f,
                              'university': g,
                              'term': h,
                              'keyword': i}, ignore_index=True)

# %% [markdown]
# Now that we've extracted all courses containing a normative keyword of interest, we need to filter our courses to only return titles that contain a normative AND a technical keyword. This is the case for all words except instances of our preprocessed `privac` and `secur`, for which we want to return all courses, even if they don't contain two keywords. To do this, we'll split the courses into two data frames, apply our respective conditions, and then merge them back together.

# %%
exceptions = oregon.loc[(oregon['keyword']=='privac') | (oregon['keyword'] =='secur')]
exceptions
# Out:
#                                                   title  dept_num  \
# 32                            NATIONAL SECURITY AFFAIRS    AS 411
# 150                        INFORMATION SYSTEMS SECURITY    BA 480
# 152                     INFORMATION SECURITY GOVERNANCE    BA 482
# 186       *COMMUNICATIONS SECURITY AND SOCIAL MOVEMENTS    CS 175
# 188                            INTRODUCTION TO SECURITY    CS 370
# 193                                    NETWORK SECURITY    CS 478
# 194                                      CYBER-SECURITY    CS 578
# 254                                    NETWORK SECURITY   ECE 478
# 258                      DATA SECURITY AND CRYPTOGRAPHY   ECE 575
# 259                                      CYBER-SECURITY   ECE 578
# 335                             FIXED INCOME SECURITIES   FIN 440
# 396     GEOSPATIAL PERSPECTIVES ON INTELLIGENCE, SEC...  GEOG 464
# 401     GEOSPATIAL PERSPECTIVES ON INTELLIGENCE, SEC...  GEOG 564
# 625                            NUCLEAR SECURITY SCIENCE   NSE 522
# 626                      NUCLEAR SECURITY SYSTEM DESIGN   NSE 525
# 786                       TERRORISM AND GLOBAL SECURITY    PS 428
# 809                       TERRORISM AND GLOBAL SECURITY    PS 528
# 1199                          NATIONAL SECURITY AFFAIRS    AS 411
# 1319                       INFORMATION SYSTEMS SECURITY    BA 480
# 1321                    INFORMATION SECURITY GOVERNANCE    BA 482
# 1355      *COMMUNICATIONS SECURITY AND SOCIAL MOVEMENTS    CS 175
# 1357                           INTRODUCTION TO SECURITY    CS 370
# 1362                                   NETWORK SECURITY    CS 478
# 1363                                     CYBER-SECURITY    CS 578
# 1423                                   NETWORK SECURITY   ECE 478
# 1427                     DATA SECURITY AND CRYPTOGRAPHY   ECE 575
# 1428                                     CYBER-SECURITY   ECE 578
# 1504                            FIXED INCOME SECURITIES   FIN 440
# 1567    GEOSPATIAL PERSPECTIVES ON INTELLIGENCE, SEC...  GEOG 464
# 1572    GEOSPATIAL PERSPECTIVES ON INTELLIGENCE, SEC...  GEOG 564
# 1869                           NUCLEAR SECURITY SCIENCE   NSE 522
# 1870                     NUCLEAR SECURITY SYSTEM DESIGN   NSE 525
# 2029                      TERRORISM AND GLOBAL SECURITY    PS 428
# 2052                      TERRORISM AND GLOBAL SECURITY    PS 528
#
#                                             description    credits  \
# 32    Emphasis on the needs for national security, e...  3 Credits
# 150   Course emphasis is on security risk mitigation...  4 Credits
# 152   As a discipline cybersecurity covers software,...  4 Credits
# 186   Equipping students with the theory and practic...  3 Credits
# 188   Introductory course on computer security with ...  4 Credits
# 193   Basic concepts and techniques in network secur...  4 Credits
# 194   A broad overview of the field of computer and ...  4 Credits
# 254   Basic concepts and techniques in network secur...  4 Credits
# 258   Secret-key and public-key cryptography, authen...  3 Credits
# 259   A broad overview of the field of computer and ...  4 Credits
# 335   Provides students with intermediate knowledge ...  4 Credits
# 396   Applications and implications of geospatial sc...  3 Credits
# 401   Applications and implications of geospatial sc...  3 Credits
# 625   Explores the nuclear fuel cycle from the persp...  4 Credits
# 626   Studies the science and engineering associated...  3 Credits
# 786   Examines US and global security in light of th...  4 Credits
# 809   Examines US and global security in light of th...  4 Credits
# 1199  Emphasis on the needs for national security, e...  3 Credits
# 1319  Course emphasis is on security risk mitigation...  4 Credits
# 1321  As a discipline cybersecurity covers software,...  4 Credits
# 1355  Equipping students with the theory and practic...  3 Credits
# 1357  Introductory course on computer security with ...  4 Credits
# 1362  Basic concepts and techniques in network secur...  4 Credits
# 1363  A broad overview of the field of computer and ...  4 Credits
# 1423  Basic concepts and techniques in network secur...  4 Credits
# 1427  Secret-key and public-key cryptography, authen...  3 Credits
# 1428  A broad overview of the field of computer and ...  4 Credits
# 1504  Provides students with intermediate knowledge ...  4 Credits
# 1567  Applications and implications of geospatial sc...  3 Credits
# 1572  Applications and implications of geospatial sc...  3 Credits
# 1869  Explores the nuclear fuel cycle from the persp...  4 Credits
# 1870  Studies the science and engineering associated...  3 Credits
# 2029  Examines US and global security in light of th...  4 Credits
# 2052  Examines US and global security in light of th...  4 Credits
#
#       instructor    syllabus               university     term keyword
# 32    Not Listed  Not Listed  Oregon State University  2019-20   secur
# 150   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 152   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 186   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 188   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 193   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 194   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 254   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 258   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 259   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 335   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 396   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 401   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 625   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 626   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 786   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 809   Not Listed  Not Listed  Oregon State University  2019-20   secur
# 1199  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1319  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1321  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1355  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1357  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1362  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1363  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1423  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1427  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1428  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1504  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1567  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1572  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1869  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 1870  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 2029  Not Listed  Not Listed  Oregon State University  2018-19   secur
# 2052  Not Listed  Not Listed  Oregon State University  2018-19   secur

# %%
#loop through technical keyword list, extract relevant titles
for word in technical:
    df = oregon[oregon['title'].str.contains(word, flags = re.IGNORECASE)]
    df['keyword2'] = word
    
#join keyword cols
df["keyword"] = df["keyword"].map(str) + "," + df["keyword2"]
df = df.drop(columns="keyword2")

df
# Out:
# C:\Users\Beverly\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Beverly\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                                                   title  dept_num  \
# 39        *EVOLUTION OF PEOPLE, TECHNOLOGY, AND SOCIETY  ANTH 330
# 88      *PHOTOGRAPHY: HISTORY, TECHNOLOGY, CULTURE A...   ART 264
# 123                *ENERGY TECHNOLOGY AND SOCIAL CHANGE   BRR 325
# 156              BUSINESS LAW - TECHNOLOGY/NEW VENTURES    BA 531
# 260     THE SCIENCE, ENGINEERING AND SOCIAL IMPACT O...  ENGR 221
# 598     THE SCIENCE, ENGINEERING AND SOCIAL IMPACT O...  MATS 221
# 624             *SOCIETAL ASPECTS OF NUCLEAR TECHNOLOGY   NSE 319
# 1011          *SCIENCE AND TECHNOLOGY IN SOCIAL CONTEXT   SOC 456
# 1029           SCIENCE AND TECHNOLOGY IN SOCIAL CONTEXT   SOC 556
# 1068                             *GENDER AND TECHNOLOGY  WGSS 320
# 1120                              GENDER AND TECHNOLOGY  WGSS 525
# 1206      *EVOLUTION OF PEOPLE, TECHNOLOGY, AND SOCIETY  ANTH 330
# 1257    *PHOTOGRAPHY: HISTORY, TECHNOLOGY, CULTURE A...   ART 264
# 1292               *ENERGY TECHNOLOGY AND SOCIAL CHANGE   BRR 325
# 1325             BUSINESS LAW - TECHNOLOGY/NEW VENTURES    BA 531
# 1429    THE SCIENCE, ENGINEERING AND SOCIAL IMPACT O...  ENGR 221
# 1842    THE SCIENCE, ENGINEERING AND SOCIAL IMPACT O...  MATS 221
# 1868            *SOCIETAL ASPECTS OF NUCLEAR TECHNOLOGY   NSE 319
# 2253          *SCIENCE AND TECHNOLOGY IN SOCIAL CONTEXT   SOC 456
# 2271           SCIENCE AND TECHNOLOGY IN SOCIAL CONTEXT   SOC 556
# 2309                             *GENDER AND TECHNOLOGY  WGSS 320
# 2361                              GENDER AND TECHNOLOGY  WGSS 525
#
#                                             description    credits  \
# 39    Overview of the evolution and prehistory of th...  3 Credits
# 88    Introduction to the history of photography thr...  3 Credits
# 123   Science and technology co-evolve with a prospe...  3 Credits
# 156   An integrative course on managing legal and et...  3 Credits
# 260   Nanotechnology is an emerging engineering fiel...  3 Credits
# 598   Nanotechnology is an emerging engineering fiel...  3 Credits
# 624   Description and discussion of nuclear-related ...  3 Credits
# 1011  Study of social aspects of science and technol...  4 Credits
# 1029  Study of social aspects of science and technol...  4 Credits
# 1068  Explores women's contributions and focuses in ...  3 Credits
# 1120  Explores women's contributions and focuses in ...  3 Credits
# 1206  Overview of the evolution and prehistory of th...  3 Credits
# 1257  Introduction to the history of photography thr...  3 Credits
# 1292  Science and technology co-evolve with a prospe...  3 Credits
# 1325  An integrative course on managing legal and et...  3 Credits
# 1429  Nanotechnology is an emerging engineering fiel...  3 Credits
# 1842  Nanotechnology is an emerging engineering fiel...  3 Credits
# 1868  Description and discussion of nuclear-related ...  3 Credits
# 2253  Study of social aspects of science and technol...  4 Credits
# 2271  Study of social aspects of science and technol...  4 Credits
# 2309  Explores women's contributions and focuses in ...  3 Credits
# 2361  Explores women's contributions and focuses in ...  3 Credits
#
#       instructor    syllabus               university     term  \
# 39    Not Listed  Not Listed  Oregon State University  2019-20
# 88    Not Listed  Not Listed  Oregon State University  2019-20
# 123   Not Listed  Not Listed  Oregon State University  2019-20
# 156   Not Listed  Not Listed  Oregon State University  2019-20
# 260   Not Listed  Not Listed  Oregon State University  2019-20
# 598   Not Listed  Not Listed  Oregon State University  2019-20
# 624   Not Listed  Not Listed  Oregon State University  2019-20
# 1011  Not Listed  Not Listed  Oregon State University  2019-20
# 1029  Not Listed  Not Listed  Oregon State University  2019-20
# 1068  Not Listed  Not Listed  Oregon State University  2019-20
# 1120  Not Listed  Not Listed  Oregon State University  2019-20
# 1206  Not Listed  Not Listed  Oregon State University  2018-19
# 1257  Not Listed  Not Listed  Oregon State University  2018-19
# 1292  Not Listed  Not Listed  Oregon State University  2018-19
# 1325  Not Listed  Not Listed  Oregon State University  2018-19
# 1429  Not Listed  Not Listed  Oregon State University  2018-19
# 1842  Not Listed  Not Listed  Oregon State University  2018-19
# 1868  Not Listed  Not Listed  Oregon State University  2018-19
# 2253  Not Listed  Not Listed  Oregon State University  2018-19
# 2271  Not Listed  Not Listed  Oregon State University  2018-19
# 2309  Not Listed  Not Listed  Oregon State University  2018-19
# 2361  Not Listed  Not Listed  Oregon State University  2018-19
#
#                keyword
# 39    societ,technolog
# 88    histor,technolog
# 123   social,technolog
# 156      law,technolog
# 260   social,technolog
# 598   social,technolog
# 624   societ,technolog
# 1011  social,technolog
# 1029  social,technolog
# 1068  gender,technolog
# 1120  gender,technolog
# 1206  societ,technolog
# 1257  histor,technolog
# 1292  social,technolog
# 1325     law,technolog
# 1429  social,technolog
# 1842  social,technolog
# 1868  societ,technolog
# 2253  social,technolog
# 2271  social,technolog
# 2309  gender,technolog
# 2361  gender,technolog

# %% [markdown]
# NOTE: the above cell is likely not the best nor most simple way to execute this step! Feel free to take special liberties here. It's probably wise to pick out a few titles that you know should be returned manually, then check to see if the script is working as desired.

# %%
#combine dfs 
oregon = pd.concat([df, exceptions])
oregon
# Out:
#                                                   title  dept_num  \
# 39        *EVOLUTION OF PEOPLE, TECHNOLOGY, AND SOCIETY  ANTH 330
# 88      *PHOTOGRAPHY: HISTORY, TECHNOLOGY, CULTURE A...   ART 264
# 123                *ENERGY TECHNOLOGY AND SOCIAL CHANGE   BRR 325
# 156              BUSINESS LAW - TECHNOLOGY/NEW VENTURES    BA 531
# 260     THE SCIENCE, ENGINEERING AND SOCIAL IMPACT O...  ENGR 221
# 598     THE SCIENCE, ENGINEERING AND SOCIAL IMPACT O...  MATS 221
# 624             *SOCIETAL ASPECTS OF NUCLEAR TECHNOLOGY   NSE 319
# 1011          *SCIENCE AND TECHNOLOGY IN SOCIAL CONTEXT   SOC 456
# 1029           SCIENCE AND TECHNOLOGY IN SOCIAL CONTEXT   SOC 556
# 1068                             *GENDER AND TECHNOLOGY  WGSS 320
# 1120                              GENDER AND TECHNOLOGY  WGSS 525
# 1206      *EVOLUTION OF PEOPLE, TECHNOLOGY, AND SOCIETY  ANTH 330
# 1257    *PHOTOGRAPHY: HISTORY, TECHNOLOGY, CULTURE A...   ART 264
# 1292               *ENERGY TECHNOLOGY AND SOCIAL CHANGE   BRR 325
# 1325             BUSINESS LAW - TECHNOLOGY/NEW VENTURES    BA 531
# 1429    THE SCIENCE, ENGINEERING AND SOCIAL IMPACT O...  ENGR 221
# 1842    THE SCIENCE, ENGINEERING AND SOCIAL IMPACT O...  MATS 221
# 1868            *SOCIETAL ASPECTS OF NUCLEAR TECHNOLOGY   NSE 319
# 2253          *SCIENCE AND TECHNOLOGY IN SOCIAL CONTEXT   SOC 456
# 2271           SCIENCE AND TECHNOLOGY IN SOCIAL CONTEXT   SOC 556
# 2309                             *GENDER AND TECHNOLOGY  WGSS 320
# 2361                              GENDER AND TECHNOLOGY  WGSS 525
# 32                            NATIONAL SECURITY AFFAIRS    AS 411
# 150                        INFORMATION SYSTEMS SECURITY    BA 480
# 152                     INFORMATION SECURITY GOVERNANCE    BA 482
# 186       *COMMUNICATIONS SECURITY AND SOCIAL MOVEMENTS    CS 175
# 188                            INTRODUCTION TO SECURITY    CS 370
# 193                                    NETWORK SECURITY    CS 478
# 194                                      CYBER-SECURITY    CS 578
# 254                                    NETWORK SECURITY   ECE 478
# 258                      DATA SECURITY AND CRYPTOGRAPHY   ECE 575
# 259                                      CYBER-SECURITY   ECE 578
# 335                             FIXED INCOME SECURITIES   FIN 440
# 396     GEOSPATIAL PERSPECTIVES ON INTELLIGENCE, SEC...  GEOG 464
# 401     GEOSPATIAL PERSPECTIVES ON INTELLIGENCE, SEC...  GEOG 564
# 625                            NUCLEAR SECURITY SCIENCE   NSE 522
# 626                      NUCLEAR SECURITY SYSTEM DESIGN   NSE 525
# 786                       TERRORISM AND GLOBAL SECURITY    PS 428
# 809                       TERRORISM AND GLOBAL SECURITY    PS 528
# 1199                          NATIONAL SECURITY AFFAIRS    AS 411
# 1319                       INFORMATION SYSTEMS SECURITY    BA 480
# 1321                    INFORMATION SECURITY GOVERNANCE    BA 482
# 1355      *COMMUNICATIONS SECURITY AND SOCIAL MOVEMENTS    CS 175
# 1357                           INTRODUCTION TO SECURITY    CS 370
# 1362                                   NETWORK SECURITY    CS 478
# 1363                                     CYBER-SECURITY    CS 578
# 1423                                   NETWORK SECURITY   ECE 478
# 1427                     DATA SECURITY AND CRYPTOGRAPHY   ECE 575
# 1428                                     CYBER-SECURITY   ECE 578
# 1504                            FIXED INCOME SECURITIES   FIN 440
# 1567    GEOSPATIAL PERSPECTIVES ON INTELLIGENCE, SEC...  GEOG 464
# 1572    GEOSPATIAL PERSPECTIVES ON INTELLIGENCE, SEC...  GEOG 564
# 1869                           NUCLEAR SECURITY SCIENCE   NSE 522
# 1870                     NUCLEAR SECURITY SYSTEM DESIGN   NSE 525
# 2029                      TERRORISM AND GLOBAL SECURITY    PS 428
# 2052                      TERRORISM AND GLOBAL SECURITY    PS 528
#
#                                             description    credits  \
# 39    Overview of the evolution and prehistory of th...  3 Credits
# 88    Introduction to the history of photography thr...  3 Credits
# 123   Science and technology co-evolve with a prospe...  3 Credits
# 156   An integrative course on managing legal and et...  3 Credits
# 260   Nanotechnology is an emerging engineering fiel...  3 Credits
# 598   Nanotechnology is an emerging engineering fiel...  3 Credits
# 624   Description and discussion of nuclear-related ...  3 Credits
# 1011  Study of social aspects of science and technol...  4 Credits
# 1029  Study of social aspects of science and technol...  4 Credits
# 1068  Explores women's contributions and focuses in ...  3 Credits
# 1120  Explores women's contributions and focuses in ...  3 Credits
# 1206  Overview of the evolution and prehistory of th...  3 Credits
# 1257  Introduction to the history of photography thr...  3 Credits
# 1292  Science and technology co-evolve with a prospe...  3 Credits
# 1325  An integrative course on managing legal and et...  3 Credits
# 1429  Nanotechnology is an emerging engineering fiel...  3 Credits
# 1842  Nanotechnology is an emerging engineering fiel...  3 Credits
# 1868  Description and discussion of nuclear-related ...  3 Credits
# 2253  Study of social aspects of science and technol...  4 Credits
# 2271  Study of social aspects of science and technol...  4 Credits
# 2309  Explores women's contributions and focuses in ...  3 Credits
# 2361  Explores women's contributions and focuses in ...  3 Credits
# 32    Emphasis on the needs for national security, e...  3 Credits
# 150   Course emphasis is on security risk mitigation...  4 Credits
# 152   As a discipline cybersecurity covers software,...  4 Credits
# 186   Equipping students with the theory and practic...  3 Credits
# 188   Introductory course on computer security with ...  4 Credits
# 193   Basic concepts and techniques in network secur...  4 Credits
# 194   A broad overview of the field of computer and ...  4 Credits
# 254   Basic concepts and techniques in network secur...  4 Credits
# 258   Secret-key and public-key cryptography, authen...  3 Credits
# 259   A broad overview of the field of computer and ...  4 Credits
# 335   Provides students with intermediate knowledge ...  4 Credits
# 396   Applications and implications of geospatial sc...  3 Credits
# 401   Applications and implications of geospatial sc...  3 Credits
# 625   Explores the nuclear fuel cycle from the persp...  4 Credits
# 626   Studies the science and engineering associated...  3 Credits
# 786   Examines US and global security in light of th...  4 Credits
# 809   Examines US and global security in light of th...  4 Credits
# 1199  Emphasis on the needs for national security, e...  3 Credits
# 1319  Course emphasis is on security risk mitigation...  4 Credits
# 1321  As a discipline cybersecurity covers software,...  4 Credits
# 1355  Equipping students with the theory and practic...  3 Credits
# 1357  Introductory course on computer security with ...  4 Credits
# 1362  Basic concepts and techniques in network secur...  4 Credits
# 1363  A broad overview of the field of computer and ...  4 Credits
# 1423  Basic concepts and techniques in network secur...  4 Credits
# 1427  Secret-key and public-key cryptography, authen...  3 Credits
# 1428  A broad overview of the field of computer and ...  4 Credits
# 1504  Provides students with intermediate knowledge ...  4 Credits
# 1567  Applications and implications of geospatial sc...  3 Credits
# 1572  Applications and implications of geospatial sc...  3 Credits
# 1869  Explores the nuclear fuel cycle from the persp...  4 Credits
# 1870  Studies the science and engineering associated...  3 Credits
# 2029  Examines US and global security in light of th...  4 Credits
# 2052  Examines US and global security in light of th...  4 Credits
#
#       instructor    syllabus               university     term  \
# 39    Not Listed  Not Listed  Oregon State University  2019-20
# 88    Not Listed  Not Listed  Oregon State University  2019-20
# 123   Not Listed  Not Listed  Oregon State University  2019-20
# 156   Not Listed  Not Listed  Oregon State University  2019-20
# 260   Not Listed  Not Listed  Oregon State University  2019-20
# 598   Not Listed  Not Listed  Oregon State University  2019-20
# 624   Not Listed  Not Listed  Oregon State University  2019-20
# 1011  Not Listed  Not Listed  Oregon State University  2019-20
# 1029  Not Listed  Not Listed  Oregon State University  2019-20
# 1068  Not Listed  Not Listed  Oregon State University  2019-20
# 1120  Not Listed  Not Listed  Oregon State University  2019-20
# 1206  Not Listed  Not Listed  Oregon State University  2018-19
# 1257  Not Listed  Not Listed  Oregon State University  2018-19
# 1292  Not Listed  Not Listed  Oregon State University  2018-19
# 1325  Not Listed  Not Listed  Oregon State University  2018-19
# 1429  Not Listed  Not Listed  Oregon State University  2018-19
# 1842  Not Listed  Not Listed  Oregon State University  2018-19
# 1868  Not Listed  Not Listed  Oregon State University  2018-19
# 2253  Not Listed  Not Listed  Oregon State University  2018-19
# 2271  Not Listed  Not Listed  Oregon State University  2018-19
# 2309  Not Listed  Not Listed  Oregon State University  2018-19
# 2361  Not Listed  Not Listed  Oregon State University  2018-19
# 32    Not Listed  Not Listed  Oregon State University  2019-20
# 150   Not Listed  Not Listed  Oregon State University  2019-20
# 152   Not Listed  Not Listed  Oregon State University  2019-20
# 186   Not Listed  Not Listed  Oregon State University  2019-20
# 188   Not Listed  Not Listed  Oregon State University  2019-20
# 193   Not Listed  Not Listed  Oregon State University  2019-20
# 194   Not Listed  Not Listed  Oregon State University  2019-20
# 254   Not Listed  Not Listed  Oregon State University  2019-20
# 258   Not Listed  Not Listed  Oregon State University  2019-20
# 259   Not Listed  Not Listed  Oregon State University  2019-20
# 335   Not Listed  Not Listed  Oregon State University  2019-20
# 396   Not Listed  Not Listed  Oregon State University  2019-20
# 401   Not Listed  Not Listed  Oregon State University  2019-20
# 625   Not Listed  Not Listed  Oregon State University  2019-20
# 626   Not Listed  Not Listed  Oregon State University  2019-20
# 786   Not Listed  Not Listed  Oregon State University  2019-20
# 809   Not Listed  Not Listed  Oregon State University  2019-20
# 1199  Not Listed  Not Listed  Oregon State University  2018-19
# 1319  Not Listed  Not Listed  Oregon State University  2018-19
# 1321  Not Listed  Not Listed  Oregon State University  2018-19
# 1355  Not Listed  Not Listed  Oregon State University  2018-19
# 1357  Not Listed  Not Listed  Oregon State University  2018-19
# 1362  Not Listed  Not Listed  Oregon State University  2018-19
# 1363  Not Listed  Not Listed  Oregon State University  2018-19
# 1423  Not Listed  Not Listed  Oregon State University  2018-19
# 1427  Not Listed  Not Listed  Oregon State University  2018-19
# 1428  Not Listed  Not Listed  Oregon State University  2018-19
# 1504  Not Listed  Not Listed  Oregon State University  2018-19
# 1567  Not Listed  Not Listed  Oregon State University  2018-19
# 1572  Not Listed  Not Listed  Oregon State University  2018-19
# 1869  Not Listed  Not Listed  Oregon State University  2018-19
# 1870  Not Listed  Not Listed  Oregon State University  2018-19
# 2029  Not Listed  Not Listed  Oregon State University  2018-19
# 2052  Not Listed  Not Listed  Oregon State University  2018-19
#
#                keyword
# 39    societ,technolog
# 88    histor,technolog
# 123   social,technolog
# 156      law,technolog
# 260   social,technolog
# 598   social,technolog
# 624   societ,technolog
# 1011  social,technolog
# 1029  social,technolog
# 1068  gender,technolog
# 1120  gender,technolog
# 1206  societ,technolog
# 1257  histor,technolog
# 1292  social,technolog
# 1325     law,technolog
# 1429  social,technolog
# 1842  social,technolog
# 1868  societ,technolog
# 2253  social,technolog
# 2271  social,technolog
# 2309  gender,technolog
# 2361  gender,technolog
# 32               secur
# 150              secur
# 152              secur
# 186              secur
# 188              secur
# 193              secur
# 194              secur
# 254              secur
# 258              secur
# 259              secur
# 335              secur
# 396              secur
# 401              secur
# 625              secur
# 626              secur
# 786              secur
# 809              secur
# 1199             secur
# 1319             secur
# 1321             secur
# 1355             secur
# 1357             secur
# 1362             secur
# 1363             secur
# 1423             secur
# 1427             secur
# 1428             secur
# 1504             secur
# 1567             secur
# 1572             secur
# 1869             secur
# 1870             secur
# 2029             secur
# 2052             secur

# %% [markdown]
# Lastly, we want to export our csv. Ideally, all csv files should be written to the courses directory in our repository.

# %%
#export as csv
oregon.to_csv('6-Oregon State University.csv')
