# %% [markdown]
# ## Johnson University Catalog Crawler

# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import re
import urllib.request #handles urls
import urllib.parse 
import linkGrabber #extracts urls
import json #encodes/decodes json 
import csv 
import requests #downloads a webpage to scrape
from bs4 import BeautifulSoup, NavigableString, Tag #beautifulsoup pulls data from HTML
import nltk #NLP tasks
from nltk import word_tokenize
from nltk.stem import PorterStemmer #removes word endings
stemmer = PorterStemmer()

# %% [markdown]
# Since Johnson's catalog is a search page with all the features being javascript interactive modules, I condensed the orinal list urls to just the singular url search page. Even for different terms, the url stays the same so condensing saves time with the loop later on.

# %%
#keyword preprocessing
def preprocess(keyword):
    keyword = keyword.lower() #lowercase
    keyword = word_tokenize(keyword) #tokenize
    for word in keyword:
        keyword = stemmer.stem(word) #stem 
    return (keyword)

#course catalog URL
url = 'https://my.jcsu.edu/ICS/Academics/'

#list of all the departments to search through 
departments = ['AES/','ACC/','XAC/','ACE/','AAS/','AAP/',
               'AER/','ARA/','ART/','BAF/','BCT/','BRC/',
               'BIL/','BIO/','RTV/','BUS/','XCA/','CW/',
               'CRE/','CHE/','CHI/','COM/','CSE/','CSC/',
               'CON/','COO/','CRM/','DRA/','ECO/','EDU/',
               'ELE/','EGR/','ENN/','ENT/','ETH/','FLF/',
               'FLS/','FL/','FRE/','FR/','GEN/','GEO/',
               'GER/','GBA/','HLT/','HCP/','HIS/','WBA/',
               'HON/','CDR/','HDR/','AEN/','CEN/','HEN/',
               'HLA/','HLS/','CPO/','HPO/','HRH/','HUM/',
               'IDS/','ITA/','JP/','JOU/','JGA/','JGD/',
               'ENG/','LAT/','LA/','LS/','LY/','MGT/',
               'XMG/','MAR/','MKT/','XMK/','MPL/','XMT/',
               'MTH/','MED/','MSC/','MUS/','XHD/','NUR/',
               'ORT/','HED/','PHI/','PEH/','PED/','PHS/',
               'PHY/','PSC/','XXX/','PLC/','LAW/','POL/',
               'RPO/','PSY/','PLS/','PUR/','RT/','RDG/',
               'REL/','NSC/','RHC/','RUS/','SCE/','SPL/',
               'SMS/','SSC/','SWK/','SOC/','SPA/','SPE/',
               'SPM/','LPD/','INS/','SUS/','TEL/','ZZZ/',
               'URB/','VBA/','VPD/','VPF/','VPG/','VPM/',
               'VPS/','VPT/','VPA/','WEL/']

# %% [markdown]
# Keyword preprocessing occurs in exactly the same manner as for the example crawler.

# %%
#import keywords
keywords = pd.read_csv("keywords.csv")
technical = keywords[(keywords['Technical/Normative']=='T') & (keywords['Include']=='Y')].Keyword
normative = keywords[(keywords['Technical/Normative']=='N') & (keywords['Include']=='Y')].Keyword
normative = [preprocess(i) for i in normative]
technical = [preprocess(i) for i in technical] 

#replace keywords of interest
normative = [w.replace('privaci', 'privac') for w in normative]
normative = [w.replace('democraci', 'democra') for w in normative]
normative = [w.replace('equiti', 'equit') for w in normative]
normative = [w.replace('histori', 'histor') for w in normative]
normative = [w.replace('justice', 'justic') for w in normative]
normative = [w.replace('liberti', 'libert') for w in normative]
normative = [w.replace('philosophi', 'philosoph') for w in normative]
normative = [w.replace('societi', 'societ') for w in normative]
normative = [w.replace('polici', 'polic') for w in normative]

technical = [w.replace('ai', '^ai') for w in technical]
technical = [w.replace('cs', '^cs') for w in technical]
technical = [w.replace('ict', '^ict') for w in technical]
technical = [w.replace('ml', '^ml') for w in technical]
technical = [w.replace('nlp', '^nlp') for w in technical]

print(normative)
print(technical)
# Out:
# ['account', 'critic', 'democra', 'discrimin', 'equal', 'equit', 'ethic', 'fair', 'femin', 'gender', 'govern', 'histor', 'inequ', 'justic', 'law', 'legal', 'libert', 'moral', 'norm', 'philosoph', 'polit', 'power', 'privac', 'race', 'religi', 'respons', 'right', 'secur', 'social', 'societ', 'surveil', 'transpar', 'valu', 'polic']
# ['^ai', 'algorithm', 'analyt', 'intellig', 'automat', 'code', 'comput', '^cs', 'cyber', 'data', 'digit', '^ict', 'inform', 'intelligen', 'internet', 'machin', '^ml', 'process', '^nlp', 'platform', 'program', 'robot', 'softwar', 'system', 'technolog']

# %% [markdown]
# The same idea as the example is followed here:
# 1. First, we want to find and extract all courses that contain any instance of a normative keyword.
# 2. Then, we want search within these courses to see if it also contains a technical keyword.
#
# The items of interest remain:
# * The course title: `title`
# * The department and course number: `dept_num`
# * The course description: `description`
# * The number of credits for the course: `credits`
# * The course instructor: `instructor`
# * The link to the course syllabus (if applicable): `syllabus`
# * The university the course is extracted from: `university`
# * The term that the course is offered during (fall, spring, summer / year): `term`
# * The keyword that triggered the extraction (this is for auditing purposes): `keyword`

# %%
#init dfs
johnson = pd.DataFrame(columns=['title','dept_num','description','credits','instructor',
                                'syllabus','university','term','keyword','URL'])
titles = []
dept_nums = []
descs = []
credit = []
profs = []
syllabi = []
uni = []
term = []     
keyword = []
URL = []

# %% [markdown]
# Part 1 is represented by the loop.

# %%
#loop through all normative words and extract relevant elements 
for dept in departments:
        page_link = url + dept
        page_response = requests.get(page_link)
        soup = BeautifulSoup(page_response.content, 'html.parser')
        courses = [p.get_text() for p in soup.find_all('a')]
        links = [r.get('href') for r in soup.find_all('a')]
        for title_pos in range(len(courses)):
            for word in normative:
                if word in courses[title_pos]:
                    print('\n', courses[title_pos], '\n', links[title_pos][links[title_pos].index('Academics'):])
                    
                    titles.append(courses[title_pos])
                    classes = links[title_pos][links[title_pos].index('Academics'):]
                    page_response2 = requests.get('https://my.jcsu.edu/ICS/'+classes)
                    soup2 = BeautifulSoup(page_response2.content, 'html.parser')
                    courses2 = [j.get_text() for j in soup2.find_all('a')]
                    links2 = [h.get('href') for h in soup2.find_all('a')]
                    print('\n', courses2, '\n', links2, '\n', len(courses2)==len(links2))
                    
                    match = links[title_pos][links[title_pos].index('Academics'):]
                    match = match[14:len(match)-1]
                    match = match.replace('_',' ')
                    for course_pos in range(len(courses2)):
                        if match in courses2[course_pos]:
                            if any(yr in ['2017','2018','2019'] for yr in links2[course_pos]):
                                page_response3 = requests.get('https://my.jcsu.edu/ICS'+links2[course_pos][1:])
                                soup3 = BeautifulSoup(page_response3.content, 'html.parser')
                                information = [j.get_text() for j in soup3.find_all('a')]

# for a,b,c,d,e,f,g,h,i,j in zip(titles,dept_nums,descs,credit,profs,syllabi,uni,term,keyword,URL):
#         johnson = johnson.append({'title': a, 
#                                     'dept_num': b,
#                                     'description': c,
#                                     'credits': d,
#                                     'instructor': e,
#                                     'syllabus': f,
#                                     'university': g,
#                                     'term': h,
#                                     'keyword': i,
#                                     'URL': j}, ignore_index=True)
# Out:
#  National Security Affairs Prep II
#  Academics/AER/AER__322/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Air Force ROTC - AER', 'National Security Affairs Prep II', 'Main Page', 'National Security Affairs Prep II', 'Main Page', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'National Security Affairs Prep II', '\n\n', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/AER/', '/ICS/Academics/AER/AER__322/', '/ICS/Academics/AER/AER__322/Main_Page.jnz', '/ICS/Academics/AER/AER__322/', '/ICS/Academics/AER/AER__322/Main_Page.jnz', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/AER/AER__322/', None, '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#
#  National Security Affairs/Prep AD
#  Academics/AER/AER__302/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Air Force ROTC - AER', 'National Security Affairs/Prep AD', 'Main Page', 'National Security Affairs/Prep AD', 'Main Page', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'National Security Affairs/Prep AD', '\n\n', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/AER/', '/ICS/Academics/AER/AER__302/', '/ICS/Academics/AER/AER__302/Main_Page.jnz', '/ICS/Academics/AER/AER__302/', '/ICS/Academics/AER/AER__302/Main_Page.jnz', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/AER/AER__302/', None, '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#
#  National Security Affairs Prep II
#  Academics/AER/AER__322/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Air Force ROTC - AER', 'National Security Affairs Prep II', 'Main Page', 'National Security Affairs Prep II', 'Main Page', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'National Security Affairs Prep II', '\n\n', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/AER/', '/ICS/Academics/AER/AER__322/', '/ICS/Academics/AER/AER__322/Main_Page.jnz', '/ICS/Academics/AER/AER__322/', '/ICS/Academics/AER/AER__322/Main_Page.jnz', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/AER/AER__322/', None, '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#
#  National Security Affairs/Prep AD
#  Academics/AER/AER__302/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Air Force ROTC - AER', 'National Security Affairs/Prep AD', 'Main Page', 'National Security Affairs/Prep AD', 'Main Page', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'National Security Affairs/Prep AD', '\n\n', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/AER/', '/ICS/Academics/AER/AER__302/', '/ICS/Academics/AER/AER__302/Main_Page.jnz', '/ICS/Academics/AER/AER__302/', '/ICS/Academics/AER/AER__302/Main_Page.jnz', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/AER/AER__302/', None, '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#  Program Planning and Evaluation
#  Academics/HED/HED__334/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Personal Health - HED', 'Program Planning and Evaluation', 'Main Page', 'Program Planning and Evaluation', 'Main Page', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'Program Planning and Evaluation', '\n\n', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/HED/', '/ICS/Academics/HED/HED__334/', '/ICS/Academics/HED/HED__334/Main_Page.jnz', '/ICS/Academics/HED/HED__334/', '/ICS/Academics/HED/HED__334/Main_Page.jnz', '/ICS/Academics/HED/HED__334/2007_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2008_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2009_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2010_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2011_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2012_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2013_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2014_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2015_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2016_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2017_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2018_20-HED__334-A/', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/HED/HED__334/', None, './Academics/HED/HED__334/2007_20-HED__334-A/', './Academics/HED/HED__334/2008_20-HED__334-A/', './Academics/HED/HED__334/2009_20-HED__334-A/', './Academics/HED/HED__334/2010_20-HED__334-A/', './Academics/HED/HED__334/2011_20-HED__334-A/', './Academics/HED/HED__334/2012_20-HED__334-A/', './Academics/HED/HED__334/2013_20-HED__334-A/', './Academics/HED/HED__334/2014_20-HED__334-A/', './Academics/HED/HED__334/2015_20-HED__334-A/', './Academics/HED/HED__334/2016_20-HED__334-A/', './Academics/HED/HED__334/2017_20-HED__334-A/', './Academics/HED/HED__334/2018_20-HED__334-A/', '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#
#  Program Planning and Evaluation
#  Academics/HED/HED__334/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Personal Health - HED', 'Program Planning and Evaluation', 'Main Page', 'Program Planning and Evaluation', 'Main Page', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'Program Planning and Evaluation', '\n\n', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'HED  334 A - Program Planning and Evaluation', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/HED/', '/ICS/Academics/HED/HED__334/', '/ICS/Academics/HED/HED__334/Main_Page.jnz', '/ICS/Academics/HED/HED__334/', '/ICS/Academics/HED/HED__334/Main_Page.jnz', '/ICS/Academics/HED/HED__334/2007_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2008_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2009_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2010_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2011_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2012_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2013_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2014_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2015_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2016_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2017_20-HED__334-A/', '/ICS/Academics/HED/HED__334/2018_20-HED__334-A/', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/HED/HED__334/', None, './Academics/HED/HED__334/2007_20-HED__334-A/', './Academics/HED/HED__334/2008_20-HED__334-A/', './Academics/HED/HED__334/2009_20-HED__334-A/', './Academics/HED/HED__334/2010_20-HED__334-A/', './Academics/HED/HED__334/2011_20-HED__334-A/', './Academics/HED/HED__334/2012_20-HED__334-A/', './Academics/HED/HED__334/2013_20-HED__334-A/', './Academics/HED/HED__334/2014_20-HED__334-A/', './Academics/HED/HED__334/2015_20-HED__334-A/', './Academics/HED/HED__334/2016_20-HED__334-A/', './Academics/HED/HED__334/2017_20-HED__334-A/', './Academics/HED/HED__334/2018_20-HED__334-A/', '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#  Measurement & Evaluation in HP
#  Academics/PED/PED__341/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Physical Education - PED', 'Measurement & Evaluation in HP', 'Main Page', 'Measurement & Evaluation in HP', 'Main Page', 'PED  341 A - Measurement & Evaluation in HP', 'PED  341 A - Measurement & Evaluation in HP', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'Measurement & Evaluation in HP', '\n\n', 'PED  341 A - Measurement & Evaluation in HP', 'PED  341 A - Measurement & Evaluation in HP', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/PED/', '/ICS/Academics/PED/PED__341/', '/ICS/Academics/PED/PED__341/Main_Page.jnz', '/ICS/Academics/PED/PED__341/', '/ICS/Academics/PED/PED__341/Main_Page.jnz', '/ICS/Academics/PED/PED__341/2012_20-PED__341-A/', '/ICS/Academics/PED/PED__341/2015_20-PED__341-A/', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/PED/PED__341/', None, './Academics/PED/PED__341/2012_20-PED__341-A/', './Academics/PED/PED__341/2015_20-PED__341-A/', '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#
#  Measurement & Evaluation in HP
#  Academics/PED/PED__341/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Physical Education - PED', 'Measurement & Evaluation in HP', 'Main Page', 'Measurement & Evaluation in HP', 'Main Page', 'PED  341 A - Measurement & Evaluation in HP', 'PED  341 A - Measurement & Evaluation in HP', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'Measurement & Evaluation in HP', '\n\n', 'PED  341 A - Measurement & Evaluation in HP', 'PED  341 A - Measurement & Evaluation in HP', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/PED/', '/ICS/Academics/PED/PED__341/', '/ICS/Academics/PED/PED__341/Main_Page.jnz', '/ICS/Academics/PED/PED__341/', '/ICS/Academics/PED/PED__341/Main_Page.jnz', '/ICS/Academics/PED/PED__341/2012_20-PED__341-A/', '/ICS/Academics/PED/PED__341/2015_20-PED__341-A/', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/PED/PED__341/', None, './Academics/PED/PED__341/2012_20-PED__341-A/', './Academics/PED/PED__341/2015_20-PED__341-A/', '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#
#  Abnormal Psychology
#  Academics/PSY/PSY__432/
#
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Psychology - PSY', 'Abnormal Psychology', 'Main Page', 'Abnormal Psychology', 'Main Page', 'PSY  432 - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 S - Abnormal Psychology', 'PSY  432 S - Abnormal Psychology', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'Abnormal Psychology', '\n\n', 'PSY  432 - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 S - Abnormal Psychology', 'PSY  432 S - Abnormal Psychology', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/PSY/', '/ICS/Academics/PSY/PSY__432/', '/ICS/Academics/PSY/PSY__432/Main_Page.jnz', '/ICS/Academics/PSY/PSY__432/', '/ICS/Academics/PSY/PSY__432/Main_Page.jnz', '/ICS/Academics/PSY/PSY__432/2007_10-PSY__432-/', '/ICS/Academics/PSY/PSY__432/2011_10-PSY__432-A/', '/ICS/Academics/PSY/PSY__432/2014_20-PSY__432-A/', '/ICS/Academics/PSY/PSY__432/2015_20-PSY__432-A/', '/ICS/Academics/PSY/PSY__432/2017_20-PSY__432-A/', '/ICS/Academics/PSY/PSY__432/2007_10-PSY__432-S/', '/ICS/Academics/PSY/PSY__432/2008_10-PSY__432-S/', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/PSY/PSY__432/', None, './Academics/PSY/PSY__432/2007_10-PSY__432-/', './Academics/PSY/PSY__432/2011_10-PSY__432-A/', './Academics/PSY/PSY__432/2014_20-PSY__432-A/', './Academics/PSY/PSY__432/2015_20-PSY__432-A/', './Academics/PSY/PSY__432/2017_20-PSY__432-A/', './Academics/PSY/PSY__432/2007_10-PSY__432-S/', './Academics/PSY/PSY__432/2008_10-PSY__432-S/', '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True
#
#  Abnormal Psychology
#  Academics/PSY/PSY__432/
#  ['Skip To Content', '', '', '', '', '', '', 'Johnson C. Smith University', 'Search', 'I forgot my password', 'Home', 'Admissions', 'Alumni', 'QEP', 'JCSU Bookstore', 'Support Services', 'Academics', 'Academics', 'Psychology - PSY', 'Abnormal Psychology', 'Main Page', 'Abnormal Psychology', 'Main Page', 'PSY  432 - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 S - Abnormal Psychology', 'PSY  432 S - Abnormal Psychology', 'JCSU IT Help Desk', 'IT Help Desk Assistance', 'My Account Info', 'JCSU eMarket', 'JCSU Canvas', 'Campus Email', 'James B. Duke Library', 'JCSU.edu', 'Golden Bull Sports', 'JCSU Bookstore', 'Abnormal Psychology', '\n\n', 'PSY  432 - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 A - Abnormal Psychology', 'PSY  432 S - Abnormal Psychology', 'PSY  432 S - Abnormal Psychology', 'Privacy Policy', 'About Us', 'Contact Us', 'Campus Directory']
#  ['#', 'https://www.facebook.com/smithites', 'https://twitter.com/JCSUniversity', 'https://www.youtube.com/user/JohnsonCSmithU', 'http://www.linkedin.com/company/johnson-c.-smith-university?utm_campaign=Argyle+Social-2013-01&utm_medium=Argyle+Social&utm_source=General+Use&utm_term=2013-01-07-17-47-37', 'http://www.pinterest.com/jcsu/', 'http://instagram.com/johnsoncsmithu', '.', "javascript:__doPostBack('ctl04$lbSearch','')", "javascript:__doPostBack('lnkForgot','')", '/ICS/', '/ICS/Admissions/', '/ICS/Alumni/', '/ICS/QEP/', '/ICS/JCSU_Bookstore/', '/ICS/Support_Services/', '/ICS/Academics/', '/ICS/Academics/', '/ICS/Academics/PSY/', '/ICS/Academics/PSY/PSY__432/', '/ICS/Academics/PSY/PSY__432/Main_Page.jnz', '/ICS/Academics/PSY/PSY__432/', '/ICS/Academics/PSY/PSY__432/Main_Page.jnz', '/ICS/Academics/PSY/PSY__432/2007_10-PSY__432-/', '/ICS/Academics/PSY/PSY__432/2011_10-PSY__432-A/', '/ICS/Academics/PSY/PSY__432/2014_20-PSY__432-A/', '/ICS/Academics/PSY/PSY__432/2015_20-PSY__432-A/', '/ICS/Academics/PSY/PSY__432/2017_20-PSY__432-A/', '/ICS/Academics/PSY/PSY__432/2007_10-PSY__432-S/', '/ICS/Academics/PSY/PSY__432/2008_10-PSY__432-S/', 'https://my.jcsu.edu/ICS/Support_Services/', 'https://www.myschoolbuilding.com/myschoolbuilding/itdgateway.asp?acctnum=899284072', 'https://my.jcsu.edu/ICS/Students/My_Account_Info.jnz', 'https://commerce.cashnet.com/jcsutickets', 'https://jcsu.instructure.com/', 'https://outlook.office365.com', 'http://library.jcsu.edu', 'http://www.jcsu.edu', 'http://www.goldenbullsports.com/', 'https://my.jcsu.edu/ICS/JCSU_Bookstore/', '/ICS/Academics/PSY/PSY__432/', None, './Academics/PSY/PSY__432/2007_10-PSY__432-/', './Academics/PSY/PSY__432/2011_10-PSY__432-A/', './Academics/PSY/PSY__432/2014_20-PSY__432-A/', './Academics/PSY/PSY__432/2015_20-PSY__432-A/', './Academics/PSY/PSY__432/2017_20-PSY__432-A/', './Academics/PSY/PSY__432/2007_10-PSY__432-S/', './Academics/PSY/PSY__432/2008_10-PSY__432-S/', '/ICS/ClientConfig/HtmlContent/Privacy.html', '/ICS/ClientConfig/HtmlContent/AboutUs.html', '/ICS/ClientConfig/HtmlContent/ContactUs.html', "javascript:__doPostBack('SiteFooter','CampusDirectory')"]
#  True

# %% [markdown]
# Now that we've extracted all courses containing a normative keyword of interest, we need to filter our courses to only return titles that contain a normative AND a technical keyword. This is the case for all words except instances of our preprocessed `privac` and `secur`, for which we want to return all courses, even if they don't contain two keywords. To do this, we'll split the courses into two data frames, apply our respective conditions, and then merge them back together.

# %%
exceptions = johnson.loc[(johnson['keyword']=='privac') | (johnson['keyword'] =='secur')]
exceptions
# Out:
#                                                  title   dept_num  \
# 20           Security and Privacy Concepts in the Wild    CS 5435
# 25                             Fixed-Income Securities   AEM 4260
# 49                          Privacy in the Digital Age    CS 5436
# 54   Practitioner's Overview of Securities Markets ...   AEM 3060
# 93           Security and Privacy Concepts in the Wild    CS 5435
# 98   National Security Affairs / Preparation for Ac...  AIRS 4401
# 123                 Internet Law, Privacy and Security   LAW 6568
# 128  Practitioner's Overview of Securities Markets ...   AEM 3060
#
#                                            description credits  \
# 20   This course will impart a technical and social...       3
# 25   Focuses on fixed-income securities including c...       4
# 49   This course introduces students to privacy tec...     3-4
# 54   A broad overview of various aspects of the Fix...       1
# 93   This course will impart a technical and social...       3
# 98   This course is designed for college seniors an...       3
# 123  This is a survey course in Internet law, with ...       3
# 128  A broad overview of various aspects of the Fix...       1
#
#          instructor                                     syllabus  \
# 20         Juels, A                                  1 available
# 25         Bogan, V                                         none
# 49    Nissenbaum, H                                         none
# 54       Edwards, A                                  1 available
# 93         Juels, A                                  1 available
# 98         Heath, M                                         none
# 123  Grimmelmann, J                                  1 available
# 128      Edwards, A                                  1 available
#
#              university         term keyword
# 20   cornell university    Fall 2017  privac
# 25   cornell university    Fall 2017   secur
# 49   cornell university  Spring 2018  privac
# 54   cornell university  Spring 2018   secur
# 93   cornell university    Fall 2018  privac
# 98   cornell university    Fall 2018   secur
# 123  cornell university  Spring 2019  privac
# 128  cornell university  Spring 2019   secur

# %%
#loop through technical keyword list, extract relevant titles
for word in technical:
    df = johnson[johnson['title'].str.contains(word, flags = re.IGNORECASE)]
    df['keyword2'] = word
    
#join keyword cols
df["keyword"] = df["keyword"].map(str) + "," + df["keyword2"]
df = df.drop(columns="keyword2")

df
# Out:
# /Users/brianavecchione/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/brianavecchione/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                                          title   dept_num  \
# 38  Gendering Religion, Science and Technology  AMST 2621
#
#                                           description credits      instructor  \
# 38  There are several "just-so stories" about scie...       4  Rock-Singer, C
#
#                                 syllabus          university         term  \
# 38                                  none  cornell university  Spring 2018
#
#              keyword
# 38  gender,technolog

# %% [markdown]
# NOTE: the above cell is likely not the best nor most simple way to execute this step! Feel free to take special liberties here. It's probably wise to pick out a few titles that you know should be returned manually, then check to see if the script is working as desired.

# %%
#combine dfs 
johnson = pd.concat([df, exceptions])
johnson
# Out:
#                                                  title   dept_num  \
# 38          Gendering Religion, Science and Technology  AMST 2621
# 20           Security and Privacy Concepts in the Wild    CS 5435
# 25                             Fixed-Income Securities   AEM 4260
# 49                          Privacy in the Digital Age    CS 5436
# 54   Practitioner's Overview of Securities Markets ...   AEM 3060
# 93           Security and Privacy Concepts in the Wild    CS 5435
# 98   National Security Affairs / Preparation for Ac...  AIRS 4401
# 123                 Internet Law, Privacy and Security   LAW 6568
# 128  Practitioner's Overview of Securities Markets ...   AEM 3060
#
#                                            description credits  \
# 38   There are several "just-so stories" about scie...       4
# 20   This course will impart a technical and social...       3
# 25   Focuses on fixed-income securities including c...       4
# 49   This course introduces students to privacy tec...     3-4
# 54   A broad overview of various aspects of the Fix...       1
# 93   This course will impart a technical and social...       3
# 98   This course is designed for college seniors an...       3
# 123  This is a survey course in Internet law, with ...       3
# 128  A broad overview of various aspects of the Fix...       1
#
#          instructor                                     syllabus  \
# 38   Rock-Singer, C                                         none
# 20         Juels, A                                  1 available
# 25         Bogan, V                                         none
# 49    Nissenbaum, H                                         none
# 54       Edwards, A                                  1 available
# 93         Juels, A                                  1 available
# 98         Heath, M                                         none
# 123  Grimmelmann, J                                  1 available
# 128      Edwards, A                                  1 available
#
#              university         term           keyword
# 38   cornell university  Spring 2018  gender,technolog
# 20   cornell university    Fall 2017            privac
# 25   cornell university    Fall 2017             secur
# 49   cornell university  Spring 2018            privac
# 54   cornell university  Spring 2018             secur
# 93   cornell university    Fall 2018            privac
# 98   cornell university    Fall 2018             secur
# 123  cornell university  Spring 2019            privac
# 128  cornell university  Spring 2019             secur

# %% [markdown]
# Lastly, we want to export our csv. Ideally, all csv files should be written to the courses directory in our repository.

# %%
#export as csv
johnson.to_csv('95-Johnson C Smith University.csv')
