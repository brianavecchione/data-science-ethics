# %% [markdown]
# ## Texas A & M University-College Station

# %% [markdown]
# This script serves as a basic tutorial for extracting courses of interest from a university. This is by no means the only (or even best way) to go about this process—so if you come up with a process that works better, feel free to implement! If you're unfamiliar with any of the libraries, the comments below annotate reasoning behind each.

# %%
import pandas as pd
import numpy as np
import re
import urllib.request #handles urls
from urllib.request import urlopen
import urllib.parse 
import linkGrabber #extracts urls
import json #encodes/decodes json 
import csv 
import requests #downloads a webpage to scrape
from bs4 import BeautifulSoup, NavigableString, Tag #beautifulsoup pulls data from HTML
import nltk #NLP tasks
from nltk import word_tokenize
from nltk.stem import PorterStemmer #removes word endings
stemmer = PorterStemmer()

# %% [markdown]
# The first thing we want to do is set up a function for standard preprocessing. It's also useful to list all of the URLs we'll need to send requests to before scraping. We want all courses within a 2 year *academic* calendar (as opposed to an annual calendar).

# %%
#keyword preprocessing
def preprocess(keyword):
    keyword = keyword.lower() #lowercase
    keyword = word_tokenize(keyword) #tokenize
    for word in keyword:
        keyword = stemmer.stem(word) #stem 
    return (keyword)

#course catalog URLs - 2 academic years 
# urls = ['https://classes.cornell.edu/search/roster/FA17?q=',
#         'https://classes.cornell.edu/search/roster/SP18?q=',
#         'https://classes.cornell.edu/search/roster/SU18?q=',
#         'https://classes.cornell.edu/search/roster/FA18?q=',
#         'https://classes.cornell.edu/search/roster/SP19?q=',
#         'https://classes.cornell.edu/search/roster/SU19?q=']

# %% [markdown]
# # Select different semesters

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://compass-ssb.tamu.edu/pls/PROD/bwckschd.p_disp_dyn_sched")


# semesters =

# %%
drop_down = driver.find_element_by_xpath("/html/body/div[3]/form/table/tbody/tr/td/select")
submit =  driver.find_element_by_xpath("/html/body/div[3]/form/input[2]")

# drop_down.send_keys("Fall 2019 - College Station")

for option in drop_down.find_elements_by_tag_name('option'):
    if option.text == 'Fall 2019 - College Station':
        option.click() # select() in earlier versions of webdriver
        break
        
submit.click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-33-b55c84c22d54> in <module>
#       6 for option in drop_down.find_elements_by_tag_name('option'):
#       7     if option.text == 'Fall 2019 - College Station':
# ----> 8         option.click() # select() in earlier versions of webdriver
#       9         break
#      10
#
# ~/.pyenv/versions/3.7.2/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/.pyenv/versions/3.7.2/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.7.2/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.pyenv/versions/3.7.2/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: call function result missing 'value'
#   (Session info: chrome=74.0.3729.169)
#   (Driver info: chromedriver=2.30.477690 (c53f4ad87510ee97b5c3425a14c0e79780cdf262),platform=Mac OS X 10.14.5 x86_64)

# %%
driver.close()

# %%
my_url = "https://compass-ssb.tamu.edu/pls/PROD/bwckschd.p_disp_dyn_sched"
raw_html = urlopen(my_url).read()
soup_doc = BeautifulSoup(raw_html, "html.parser")

soup_doc
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache" http-equiv="Pragma" name="Cache-Control"/>
# <meta content="no-cache, max-age=0, must-revalidate" http-equiv="Cache-Control" name="Cache-Control"/>
# <link href="/css/web_defaultapp.css" rel="stylesheet" type="text/css"/>
# <link href="/css/web_defaultprint.css" media="print" rel="stylesheet" type="text/css"/>
# <title>Class Schedule Search</title>
# <meta content="text/javascript" http-equiv="Content-Script-Type" name="Default_Script_Language"/>
# <script language="JavaScript" type="text/javascript">
# <!-- Hide JavaScript from older browsers
# window.onunload = function() {submitcount=0;}
# var submitcount=0;
# function checkSubmit() {
# if (submitcount == 0)
#    {
#    submitcount++;
#    return true;
#    }
# else
#    {
# alert("Your changes have already been submitted.");
#    return false;
#    }
# }
# //  End script hiding -->
# </script>
# <script language="JavaScript" type="text/javascript">
# <!-- Hide JavaScript from older browsers
# //  Function to open a window
# function windowOpen(window_url) {
#    helpWin = window.open(window_url,'','toolbar=yes,status=no,scrollbars=yes,menubar=yes,resizable=yes,directories=no,location=no,width=350,height=400');
#    if (document.images) {
#        if (helpWin) helpWin.focus()
#    }
# }
# //  End script hiding -->
# </script>
# </head>
# <script>
#                     if(self==top){
#                      // this means its in standalone SSB
#                      document.write('<body>');
#                     }
#                     else{ // coming thorugh portal
#                     document.write('<style> DIV.pageheaderdiv1 {margin-top: 10px;} </style>');
#                     document.write('<body class="campuspipeline">'); // class=campuspipeline shows the header image
#                     }
#                  </script>
# <div class="headerwrapperdiv">
# <div class="pageheaderdiv1">
# <a class="skiplinks" href="#main_content" onblur="window.status=''; return true" onfocus="window.status='Go to Main Content'; return true" onmouseout="window.status=''; return true" onmouseover="window.status='Go to Main Content'; return true">Go to Main Content</a>
# </div>
# <table class="plaintable" summary="This table displays Menu Items and Banner Search textbox." width="100%">
# <tr>
# <td class="pldefault">
# <div class="headerlinksdiv2">
#
# </div>
# </td>
# <td class="pldefault"><p class="rightaligntext" p="">
# <span class="pageheaderlinks">
# <script>
# if(self==top){
#  // this means its in standalone SSB
#  document.write('<div style="padding-top:1px;color:#F8CF66;margin-bottom:5px;padding-bottom:5px;position:relative;right: -85px;">&nbsp;</div>');
# }
# else{
#   //document.write('<span style="padding-top:25px;color:#F8CF66;margin-bottom:15px;padding-bottom:15px;position:absolute;right: 45px;">');
#   document.write('<div style="padding-top:25px;color:#F8CF66;margin-bottom:5px;padding-bottom:5px;position:relative;right: -85px;">');
#   document.write('<input style="background: none repeat scroll 0% 0% transparent;border: medium none; cursor: pointer; -moz-user-select: text; text-decoration: underline; color:Blue;font: bold 12px,helvetica,sans-serif;" type="button" value="Print" onClick="myprint()" />');
#   //document.write('</span><br clear="all" />');
#   document.write('</div>');
# }
# </script>
# </span>
# </p></td>
# </tr>
# </table>
# </div>
# <div class="pagetitlediv">
# <table class="plaintable" summary="This table displays title and static header displays." width="100%">
# <tr>
# <td class="pldefault">
# <h2>Class Schedule Search</h2>
# </td>
# <td class="pldefault">
#
# </td>
# <td class="pldefault"><p class="rightaligntext" p="">
# <div class="staticheaders">
# </div>
# </p></td>
# </tr>
# <tr>
# <td colspan="3" style="background-color:#500000;" width="100%"><img alt="Transparent Image" border="0" class="headerImg" height="3" hspace="0" name="web_transparent" src="/wtlgifs/web_transparent.gif" title="Transparent Image" vspace="0" width="10"/></td>
# </tr>
# </table>
# <a name="main_content"></a>
# </div>
# <div class="pagebodydiv">
# <!--  ** END OF twbkwbis.P_OpenDoc **  -->
# <form action="/pls/PROD/bwckgens.p_proc_term_date" method="post" onsubmit="return checkSubmit()">
# <input name="p_calling_proc" type="hidden" value="bwckschd.p_disp_dyn_sched"/>
# <table class="dataentrytable" summary="This layout table is used for term selection." width="100%"><caption class="captiontext">Search by Term: </caption>
# <tr>
# <td class="dedefault"><label for="term_input_id"><span class="fieldlabeltextinvisible">Term</span></label>
# <select bypass_esc="" name="p_term" size="1">"Y" ID="term_input_id"&gt;
# <option value="">None</option>
# <option value="201931">Fall 2019 - College Station</option>
# <option value="201932">Fall 2019 - Galveston</option>
# <option value="201933">Fall 2019 - Qatar</option>
# <option value="201935">Fall 2019 - Half Year Term</option>
# <option value="201921">Summer 2019 - College Station</option>
# <option value="201922">Summer 2019 - Galveston</option>
# <option value="201923">Summer 2019 - Qatar</option>
# <option value="201911">Spring 2019 - College Station (View only)</option>
# <option value="201912">Spring 2019 - Galveston (View only)</option>
# <option value="201913">Spring 2019 - Qatar (View only)</option>
# <option value="201915">Spring 2019 - Half Year Term (View only)</option>
# <option value="201941">Full Yr Professional 2019-2020 (View only)</option>
# <option value="201831">Fall 2018 - College Station (View only)</option>
# <option value="201832">Fall 2018 - Galveston (View only)</option>
# <option value="201833">Fall 2018 - Qatar (View only)</option>
# <option value="201835">Fall 2018 - Half Year Term (View only)</option>
# <option value="201821">Summer 2018 - College Station (View only)</option>
# <option value="201822">Summer 2018 - Galveston (View only)</option>
# <option value="201823">Summer 2018 - Qatar (View only)</option>
# <option value="201811">Spring 2018 - College Station (View only)</option>
# <option value="201812">Spring 2018 - Galveston (View only)</option>
# <option value="201813">Spring 2018 - Qatar (View only)</option>
# <option value="201815">Spring 2018 - Half Year Term (View only)</option>
# <option value="201841">Full Yr Professional 2018-2019 (View only)</option>
# <option value="201731">Fall 2017 - College Station (View only)</option>
# <option value="201732">Fall 2017 - Galveston (View only)</option>
# <option value="201733">Fall 2017 - Qatar (View only)</option>
# <option value="201735">Fall 2017 - Half Year Term (View only)</option>
# <option value="201721">Summer 2017 - College Station (View only)</option>
# <option value="201722">Summer 2017 - Galveston (View only)</option>
# <option value="201723">Summer 2017 - Qatar (View only)</option>
# <option value="201711">Spring 2017 - College Station (View only)</option>
# <option value="201712">Spring 2017 - Galveston (View only)</option>
# <option value="201713">Spring 2017 - Qatar (View only)</option>
# <option value="201741">Full Yr Professional 2017-2018 (View only)</option>
# <option value="201631">Fall 2016 - College Station (View only)</option>
# <option value="201632">Fall 2016 - Galveston (View only)</option>
# <option value="201633">Fall 2016 - Qatar (View only)</option>
# <option value="201621">Summer 2016 - College Station (View only)</option>
# <option value="201622">Summer 2016 - Galveston (View only)</option>
# <option value="201623">Summer 2016 - Qatar (View only)</option>
# <option value="201611">Spring 2016 - College Station (View only)</option>
# <option value="201612">Spring 2016 - Galveston (View only)</option>
# <option value="201613">Spring 2016 - Qatar (View only)</option>
# <option value="201641">Full Yr Professional 2016-2017 (View only)</option>
# <option value="201531">Fall 2015 - College Station (View only)</option>
# <option value="201532">Fall 2015 - Galveston (View only)</option>
# <option value="201533">Fall 2015 - Qatar (View only)</option>
# <option value="201521">Summer 2015 - College Station (View only)</option>
# <option value="201522">Summer 2015 - Galveston (View only)</option>
# <option value="201523">Summer 2015 - Qatar (View only)</option>
# <option value="201511">Spring 2015 - College Station (View only)</option>
# <option value="201512">Spring 2015 - Galveston (View only)</option>
# <option value="201513">Spring 2015 - Qatar (View only)</option>
# <option value="201541">Full Yr Professional 2015-2016 (View only)</option>
# <option value="201431">Fall 2014 - College Station (View only)</option>
# <option value="201432">Fall 2014 - Galveston (View only)</option>
# <option value="201433">Fall 2014 - Qatar (View only)</option>
# <option value="201421">Summer 2014 - College Station (View only)</option>
# <option value="201422">Summer 2014 - Galveston (View only)</option>
# <option value="201423">Summer 2014 - Qatar (View only)</option>
# <option value="201411">Spring 2014 - College Station (View only)</option>
# <option value="201412">Spring 2014 - Galveston (View only)</option>
# <option value="201413">Spring 2014 - Qatar (View only)</option>
# <option value="201441">Full Yr Professional 2014-2015 (View only)</option>
# <option value="201331">Fall 2013 - College Station (View only)</option>
# <option value="201332">Fall 2013 - Galveston (View only)</option>
# <option value="201333">Fall 2013 - Qatar (View only)</option>
# <option value="201321">Summer 2013 - College Station (View only)</option>
# <option value="201322">Summer 2013 - Galveston (View only)</option>
# <option value="201323">Summer 2013 - Qatar (View only)</option>
# <option value="201311">Spring 2013 - College Station (View only)</option>
# <option value="201312">Spring 2013 - Galveston (View only)</option>
# <option value="201313">Spring 2013 - Qatar (View only)</option>
# <option value="201341">Full Yr Professional 2013-2014 (View only)</option>
# <option value="201231">Fall 2012 - College Station (View only)</option>
# <option value="201232">Fall 2012 - Galveston (View only)</option>
# <option value="201233">Fall 2012 - Qatar (View only)</option>
# <option value="201221">Summer 2012 - College Station (View only)</option>
# <option value="201222">Summer 2012 - Galveston (View only)</option>
# <option value="201223">Summer 2012 - Qatar (View only)</option>
# <option value="201211">Spring 2012 - College Station (View only)</option>
# <option value="201212">Spring 2012 - Galveston (View only)</option>
# <option value="201213">Spring 2012 - Qatar (View only)</option>
# <option value="201241">Full Yr Professional 2012-2013 (View only)</option>
# <option value="201131">Fall 2011 - College Station (View only)</option>
# <option value="201132">Fall 2011 - Galveston (View only)</option>
# <option value="201133">Fall 2011 - Qatar (View only)</option>
# <option value="201121">Summer 2011 - College Station (View only)</option>
# <option value="201122">Summer 2011 - Galveston (View only)</option>
# <option value="201123">Summer 2011 - Qatar (View only)</option>
# <option value="201111">Spring 2011 - College Station (View only)</option>
# <option value="201112">Spring 2011 - Galveston (View only)</option>
# <option value="201113">Spring 2011 - Qatar (View only)</option>
# <option value="201141">Full Yr Professional 2011-2012 (View only)</option>
# <option value="201031">Fall 2010 - College Station (View only)</option>
# <option value="201032">Fall 2010 - Galveston (View only)</option>
# <option value="201033">Fall 2010 - Qatar (View only)</option>
# <option value="201021">Summer 2010 - College Station (View only)</option>
# <option value="201022">Summer 2010 - Galveston (View only)</option>
# <option value="201023">Summer 2010 - Qatar (View only)</option>
# <option value="201011">Spring 2010 - College Station (View only)</option>
# <option value="201012">Spring 2010 - Galveston (View only)</option>
# <option value="201013">Spring 2010 - Qatar (View only)</option>
# <option value="201041">Full Yr Professional 2010-2011 (View only)</option>
# <option value="200931">Fall 2009 - College Station (View only)</option>
# <option value="200932">Fall 2009 - Galveston (View only)</option>
# <option value="200933">Fall 2009 - Qatar (View only)</option>
# <option value="200941">Full Yr Professional 2009-2010 (View only)</option>
# </select>
# </td>
# </tr>
# </table>
# <br/>
# <br/>
# <input type="submit" value="Submit"/>
# <input type="reset" value="Reset"/>
# </form>
# <script language="JavaScript">
#
#     <!--
#       function myprint() {
#
#         window.print();
#         }
#        //--></script>
# <script>
# if(self==top){
#  // this means its in standalone SSB
# }
# else{
#   document.write('<span style="padding-top:25px;color:#F8CF66;margin-bottom:15px;padding-bottom:15px;position:absolute;right: 45px;">');
#   document.write('<input style="background: none repeat scroll 0% 0% transparent;border: medium none; cursor: pointer; -moz-user-select: text; text-decoration: underline; color:Blue;font: bold 12px,helvetica,sans-serif;" type="button" value="Print" onClick="myprint()" />');
#   document.write('</span>');
# }
# </script>
# <!--  ** START OF twbkwbis.P_CloseDoc **  -->
# <table border="0" cellpadding="0" cellspacing="0" class="plaintable" summary="This is table displays line separator at end of the page." width="100%"><tr><td colspan="2" style="background-color:#e7ddcb;" width="100%"><img alt="Transparent Image" border="0" class="headerImg" height="3" hspace="0" name="web_transparent" src="/wtlgifs/web_transparent.gif" title="Transparent Image" vspace="0" width="10"/></td></tr></table>
# <a class="skiplinks" href="#top" onblur="window.status=''; return true" onfocus="window.status='Skip to top of page'; return true" onmouseout="window.status=''; return true" onmouseover="window.status='Skip to top of page'; return true">Skip to top of page</a>
# </div>
# <div class="footerbeforediv">
# </div>
# <div class="footerafterdiv">
# </div>
# <div class="globalafterdiv">
# </div>
# <div class="globalfooterdiv">
# </div>
# <div class="pagefooterdiv">
# </div>
# <div class="poweredbydiv">
# </div>
# <div class="div1"></div>
# <div class="div2"></div>
# <div class="div3"></div>
# <div class="div4"></div>
# <div class="div5"></div>
# <div class="div6"></div>
# <iframe src="/wtlgifs/ServerName.html" style="width:100px;height:50px;border:none;font-size:9px"></iframe>
# </html>

# %% [markdown]
# Next, we'll want to import our keyword csv, split our keyword lists, and preprocess them. The way the csv is set up, we'll want to split the words that are indicated as technical (`T`) or normative (`N`) and that we've chosen to include (`Y`). You'll notice that preprocessing is useful for some of our words but not for others. Here, we've chosen to manually alter words that are not usefully preprocessed. In this case, it means replacing instances of words that are stemmed to end in i.
#
# [regex is a bitch here]

# %%
#import keywords
keywords = pd.read_csv("../keywords.csv")
technical = keywords[(keywords['Technical/Normative']=='T') & (keywords['Include']=='Y')].Keyword
normative = keywords[(keywords['Technical/Normative']=='N') & (keywords['Include']=='Y')].Keyword
normative = [preprocess(i) for i in normative]
technical = [preprocess(i) for i in technical] 

#replace keywords of interest
normative = [w.replace('privaci', 'privac') for w in normative]
normative = [w.replace('democraci', 'democra') for w in normative]
normative = [w.replace('equiti', 'equit') for w in normative]
normative = [w.replace('histori', 'histor') for w in normative]
normative = [w.replace('justice', 'justic') for w in normative]
normative = [w.replace('liberti', 'libert') for w in normative]
normative = [w.replace('philosophi', 'philosoph') for w in normative]
normative = [w.replace('societi', 'societ') for w in normative]
normative = [w.replace('polici', 'polic') for w in normative]

technical = [w.replace('ai', '^ai') for w in technical]
technical = [w.replace('cs', '^cs') for w in technical]
technical = [w.replace('ict', '^ict') for w in technical]
technical = [w.replace('ml', '^ml') for w in technical]
technical = [w.replace('nlp', '^nlp') for w in technical]

print(normative)
print(technical)
# Out:
# ['account', 'critic', 'democra', 'discrimin', 'equal', 'equit', 'ethic', 'fair', 'femin', 'gender', 'govern', 'histor', 'inequ', 'justic', 'law', 'legal', 'libert', 'moral', 'norm', 'philosoph', 'polit', 'power', 'privac', 'race', 'religi', 'respons', 'right', 'secur', 'social', 'societ', 'surveil', 'transpar', 'valu', 'polic']
# ['^ai', 'algorithm', 'analyt', 'intellig', 'automat', 'code', 'comput', '^cs', 'cyber', 'data', 'digit', '^ict', 'inform', 'intelligen', 'internet', 'machin', '^ml', 'process', '^nlp', 'platform', 'program', 'robot', 'softwar', 'system', 'technolog']

# %% [markdown]
# The process behind extracting relevant courses works in two steps:
# 1. First, we want to find and extract all courses that contain any instance of a normative keyword.
# 2. Then, we want search within these courses to see if it also contains a technical keyword.
#
# We initialize a data frame with columns for all of the course items we want to extract. It probably makes the most sense to standardize these feature names across all university scripts so that they're easier to merge in the final compiled dataset for all universities. Our items of interest are:
# * The course title: `title`
# * The department and course number: `dept_num`
# * The course description: `description`
# * The number of credits for the course: `credits`
# * The course instructor: `instructor`
# * The link to the course syllabus (if applicable): `syllabus`
# * The university the course is extracted from: `university`
# * The term that the course is offered during (fall, spring, summer / year): `term`
# * The keyword that triggered the extraction (this is for auditing purposes): `keyword`

# %%
#init dfs
cornell = pd.DataFrame(columns=['title','dept_num','description','credits','instructor',
                                'syllabus','university','term','keyword'])

# %% [markdown]
# The loop below executes part 1 of our extraction. It's long and kind of messy (sorry), so feel free to play around with the structure if you'd like. The key tasks here are to extract our items of interest based on our search queries and append them to our data frame.

# %%
#roster search for all urls
for url in urls:
    #loop through all normative words and extract relevant elements 
    for word in normative: 
        url_keyword = url + word #NOTE:this structure will likely be different between rosters!
        response = requests.get(url_keyword)
        soup = BeautifulSoup(response.content, 'lxml')
        #extract relevant elements 
        titles = [p.get_text() for p in soup.select(".title-coursedescr")] #get full desc
        dept_nums = [p.get_text() for p in soup.select('.title-subjectcode')]
        descs = [p.get_text() for p in soup.select('.course-descr')]
        credit = [p.get_text() for p in soup.select('.credit-val')]
        profs = [p.get_text() for p in soup.select('.instructors span.tooltip-iws')]
        syllabi = [p.get_text() for p in soup.select('.enrlgrp-syllabi')] #TODO: extract syllabi link
        syllabi = [p.replace('Syllabi:\n','') for p in syllabi] 
        uni = ['cornell university']
        term = [btn.get_text().strip() for btn in soup.select('button',{'class':'btn btn-default dropdown-toggle'})[:1]]       
        keyword = [word]
        for a,b,c,d,e,f,g,h,i in zip(titles,dept_nums,descs,credit,profs,syllabi,uni,term,keyword):
            cornell = cornell.append({'title': a, 
                                        'dept_num': b,
                                        'description': c,
                                        'credits': d,
                                        'instructor': e,
                                        'syllabus': f,
                                        'university': g,
                                        'term': h,
                                        'keyword': i}, ignore_index=True)

cornell
# Out:
#                                                  title    dept_num  \
# 0                                 Financial Accounting    AEM 2210
# 1    Telling to Live: Critical Examinations of Test...   AMST 3680
# 2               Populism, Democracy & Authoritarianism   GOVT 3284
# 3                Employment Discrimination and the Law  ILRLR 4842
# 4                       Controversies About Inequality   AMST 2225
# 5          Structural Barriers to Equity in Planning I    CRP 3106
# 6         Engineering Ethics and Professional Practice    BEE 5400
# 7    National Security Affairs / Preparation for Ac...   AIRS 4401
# 8                        Topics in Feminist Media Arts   ARTH 4153
# 9    Race, Gender, and Crossing Water: Narratives o...   AMST 6650
# 10    Introduction to American Government and Politics   AMST 1115
# 11                           History Goes to Hollywood   AMST 1575
# 12                      Controversies About Inequality   AMST 2225
# 13   FWS: The Color and Class of Water: Environment...   ASRC 1846
# 14                                  Psychology and Law    LAW 2650
# 15             Advanced Legal Research in Business Law    LAW 6051
# 16                           Moral Dilemmas in the Law   GOVT 2432
# 17   Thinking from a Different Place: Indigenous Ph...   AIIS 3560
# 18   America, Business and International Political ...    AEM 3547
# 19         The Evolution of USAF Air and Space Power I   AIRS 2201
# 20           Security and Privacy Concepts in the Wild     CS 5435
# 21   Race and Ethnicity in the United States: Socia...   AMST 1104
# 22   Staging Faith: Contemporary Theatre and Lived ...   AMST 3747
# 23   Incarceration, Policy Response, and Self-Refle...   AMST 3142
# 24              Organizing for Immigrant Worker Rights  ILRLR 3068
# 25                             Fixed-Income Securities    AEM 4260
# 26   Social Entrepreneurs, Innovators, and Problem ...    AEM 3380
# 27                    Inventing an Information Society   AMST 2980
# 28                           Energy Value Chain Module  CHEME 6641
# 29   Toward a Sustainable Global Food System: Food ...    AEM 4450
# ..                                                 ...         ...
# 116  Freedom Writes: Literature of Global Justice S...   ASRC 2870
# 117                         Competition Law and Policy    LAW 4021
# 118                 Legal Aspects of Land Use Planning    CRP 4590
# 119                       Markets, Morals, and Methods    LAW 7580
# 120  Locke and the Philosophies of Dispossession: I...   AIIS 4200
# 121                       Political Economy of the WTO    AEM 4350
# 122          Black Power Movement and Transnationalism   AMST 6321
# 123                 Internet Law, Privacy and Security    LAW 6568
# 124                         Race and Modern US History    AAS 2641
# 125             Black Spirituality, Religion & Protest   AMST 2112
# 126  Incarceration, Policy Response, and Self-Refle...   AMST 3142
# 127  FWS: Indigeneity as Rights: Haudenosaunee Righ...   AIIS 1123
# 128  Practitioner's Overview of Securities Markets ...    AEM 3060
# 129  Social Entrepreneurship Practicum: Anabel's Gr...    AEM 3385
# 130                      American Society through Film   AMST 1290
# 131  Applied Accounting: Finding Value Beyond Funda...    AEM 3355
# 132                   Dairy Markets and Policy Seminar    AEM 3040
# 133                               Financial Accounting    AEM 2210
# 134  Strategies for College Success: Critical Think...     HE 1105
# 135                Information Ethics, Law, and Policy   INFO 1200
# 136  History and Politics of the Modern and Contemp...   GOVT 2623
# 137            Int'l Human Rights in Theory & Practice    LAW 3887
# 138                          The American Legal System   GOVT 3150
# 139                          Contemporary Moral Issues   PHIL 1450
# 140                         Introduction to Philosophy   PHIL 1100
# 141     Literature, Politics, and Genocide in Cambodia  ASIAN 2225
# 142            Int'l Human Rights in Theory & Practice   GOVT 3887
# 143  Social Entrepreneurs, Innovators, and Problem ...    AEM 3380
# 144                     Nutrition, Health, and Society     NS 1150
# 145    Introduction to Macroeconomic Theory and Policy    AEM 1300
#
#                                            description credits  \
# 0    Comprehensive introduction to financial accoun...       3
# 1    Testimonio is a type of writing known in Latin...       4
# 2    Populist leaders, movements, and parties who c...       4
# 3    Examines the laws against employment discrimin...       4
# 4    In recent years, poverty and inequality have b...       4
# 5    This seminar will take a critical look at stru...       1
# 6    An in-depth treatment of the ethical issues fa...       3
# 7    This course is concerned with the national sec...       3
# 8    Feminist media arts continuously proliferate. ...       4
# 9    This course explores movement through and acro...       4
# 10   A policy-centered approach to the study of gov...       4
# 11   From the inception of the film industry, depic...       4
# 12   In recent years, poverty and inequality have b...       4
# 13   The lead crisis in Flint, Michigan and the pro...       3
# 14   This course explores how cognitive, social & c...       4
# 15   Business issues, particularly those relating t...       1
# 16   The course concerns the principles and philoso...       4
# 17   The Western nation-state has failed to solve t...       4
# 18   Do you want to learn the discussion-based case...       4
# 19   This course is designed to examine general asp...       1
# 20   This course will impart a technical and social...       3
# 21   This course will examine race and ethnic relat...       3
# 22   Religious beliefs, practices, and conflicts sh...       3
# 23   This class is intended to provoke some hard th...     1-4
# 24   This class examines the institutional processe...       4
# 25   Focuses on fixed-income securities including c...       4
# 26   Introduces students to the social entrepreneur...       4
# 27   Explores the history of information technology...       3
# 28   Module of CHEME 6640. Energy value and supply ...       1
# 29   Comprehensive presentation and discussion of p...       3
# ..                                                 ...     ...
# 116  This course examines some major justice moveme...       4
# 117  This course will examine issues that arise whe...       4
# 118  Survey of leading cases and legal concepts in ...       4
# 119  This seminar is devoted to the foundations of ...       3
# 120  This course looks at the philosopher John Lock...       3
# 121  The politics of the WTO and trade policy are e...       3
# 122  This seminar explores the international and tr...       4
# 123  This is a survey course in Internet law, with ...       3
# 124  This course surveys modern U.S. history, from ...       4
# 125  This course examines Black spirituality, relig...       4
# 126  This class is intended to provoke some hard th...     1-4
# 127  The 20th century Haudenosaunee delegations to ...       3
# 128  A broad overview of various aspects of the Fix...       1
# 129  A seminar course with a practicum in managemen...       3
# 130  Introduces students to the sociological analys...       3
# 131  Applied Accounting examines the information co...       3
# 132  This course is a survey of topics related to: ...       2
# 133  Comprehensive introduction to financial accoun...       3
# 134  Designed to provide students with the academic...       2
# 135  This course investigates the ethical, legal, a...       3
# 136  This course examines the history and politics ...       3
# 137      No description available. view course details       3
# 138  This course offers a comprehensive introductio...       4
# 139  An introduction to some of the main contempora...       3
# 140  A general introduction to some of the main top...       3
# 141  This course will examine various literary, his...       3
# 142      No description available. view course details       3
# 143  Introduces students to the social entrepreneur...     3-4
# 144  Discusses the facts and fallacies concerning t...       3
# 145  This course is an introduction to macroeconomi...       3
#
#               instructor                                     syllabus  \
# 0            Sinclair, J                                  1 available
# 1                Diaz, E                                         none
# 2             Roberts, K                                         none
# 3          Lieberwitz, R                                         none
# 4             Haskins, A                                  1 available
# 5             Edmonds, K                                  1 available
# 6               Evans, R                                  1 available
# 7               Heath, M                                         none
# 8           Fernandez, M                                         none
# 9             Samuels, S                                         none
# 10            Mettler, S                                         none
# 11         Von Eschen, P                                         none
# 12            Haskins, A                                  1 available
# 13        Pendergrast, T                                         none
# 14               Hans, V                                         none
# 15           Morrison, M                                         none
# 16             Marmor, A                                  1 available
# 17           Cheyfitz, E                                         none
# 18        Katzenstein, P                                  1 available
# 19             Torres, J                                         none
# 20              Juels, A                                  1 available
# 21           Alvarado, S                                         none
# 22             Gainor, J                                         none
# 23             Sawyer, P                                         none
# 24            Gleeson, S                                         none
# 25              Bogan, V                                         none
# 26            Wessels, A                                         none
# 27              Kline, R                                  1 available
# 28           Quraishi, M                                  1 available
# 29            Pingali, P                                  1 available
# ..                   ...                                          ...
# 116            Sawyer, P                                  1 available
# 117               Hay, G                                  1 available
# 118             Booth, R                                  1 available
# 119           Hockett, R                                         none
# 120        Richardson, T                                  1 available
# 121         de Gorter, H                                         none
# 122          Rickford, R                                         none
# 123       Grimmelmann, J                                  1 available
# 124             Chang, D                                         none
# 125        Washington, M                                         none
# 126              Reed, M                                         none
# 127  Piasta-Mansfield, U                                  1 available
# 128           Edwards, A                                  1 available
# 129           Wessels, A                                         none
# 130            Strang, D                                         none
# 131          Sinclair, J                                         none
# 132         Novakovic, A                                  1 available
# 133          Sinclair, J                                         none
# 134            Furnas, H                                         none
# 135              Jack, M                                         none
# 136             Brann, R                                         none
# 137          Brundige, E                                         none
# 138           Stewart, C                                         none
# 139             Sethi, N                                         none
# 140         Korzukhin, T                                         none
# 141            Chigas, G                                         none
# 142          Brundige, E                                         none
# 143           Wessels, A                                         none
# 144          Levitsky, D                                  1 available
# 145              Basu, A                                         none
#
#              university         term    keyword
# 0    cornell university    Fall 2017    account
# 1    cornell university    Fall 2017     critic
# 2    cornell university    Fall 2017    democra
# 3    cornell university    Fall 2017  discrimin
# 4    cornell university    Fall 2017      equal
# 5    cornell university    Fall 2017      equit
# 6    cornell university    Fall 2017      ethic
# 7    cornell university    Fall 2017       fair
# 8    cornell university    Fall 2017      femin
# 9    cornell university    Fall 2017     gender
# 10   cornell university    Fall 2017     govern
# 11   cornell university    Fall 2017     histor
# 12   cornell university    Fall 2017      inequ
# 13   cornell university    Fall 2017     justic
# 14   cornell university    Fall 2017        law
# 15   cornell university    Fall 2017      legal
# 16   cornell university    Fall 2017      moral
# 17   cornell university    Fall 2017  philosoph
# 18   cornell university    Fall 2017      polit
# 19   cornell university    Fall 2017      power
# 20   cornell university    Fall 2017     privac
# 21   cornell university    Fall 2017       race
# 22   cornell university    Fall 2017     religi
# 23   cornell university    Fall 2017    respons
# 24   cornell university    Fall 2017      right
# 25   cornell university    Fall 2017      secur
# 26   cornell university    Fall 2017     social
# 27   cornell university    Fall 2017     societ
# 28   cornell university    Fall 2017       valu
# 29   cornell university    Fall 2017      polic
# ..                  ...          ...        ...
# 116  cornell university  Spring 2019     justic
# 117  cornell university  Spring 2019        law
# 118  cornell university  Spring 2019      legal
# 119  cornell university  Spring 2019      moral
# 120  cornell university  Spring 2019  philosoph
# 121  cornell university  Spring 2019      polit
# 122  cornell university  Spring 2019      power
# 123  cornell university  Spring 2019     privac
# 124  cornell university  Spring 2019       race
# 125  cornell university  Spring 2019     religi
# 126  cornell university  Spring 2019    respons
# 127  cornell university  Spring 2019      right
# 128  cornell university  Spring 2019      secur
# 129  cornell university  Spring 2019     social
# 130  cornell university  Spring 2019     societ
# 131  cornell university  Spring 2019       valu
# 132  cornell university  Spring 2019      polic
# 133  cornell university  Summer 2019    account
# 134  cornell university  Summer 2019     critic
# 135  cornell university  Summer 2019      ethic
# 136  cornell university  Summer 2019     histor
# 137  cornell university  Summer 2019        law
# 138  cornell university  Summer 2019      legal
# 139  cornell university  Summer 2019      moral
# 140  cornell university  Summer 2019  philosoph
# 141  cornell university  Summer 2019      polit
# 142  cornell university  Summer 2019      right
# 143  cornell university  Summer 2019     social
# 144  cornell university  Summer 2019     societ
# 145  cornell university  Summer 2019      polic
#
# [146 rows x 9 columns]

# %% [markdown]
# Now that we've extracted all courses containing a normative keyword of interest, we need to filter our courses to only return titles that contain a normative AND a technical keyword. This is the case for all words except instances of our preprocessed `privac` and `secur`, for which we want to return all courses, even if they don't contain two keywords. To do this, we'll split the courses into two data frames, apply our respective conditions, and then merge them back together.

# %%
exceptions = cornell.loc[(cornell['keyword']=='privac') | (cornell['keyword'] =='secur')]
exceptions
# Out:
#                                                  title   dept_num  \
# 20           Security and Privacy Concepts in the Wild    CS 5435
# 25                             Fixed-Income Securities   AEM 4260
# 49                          Privacy in the Digital Age    CS 5436
# 54   Practitioner's Overview of Securities Markets ...   AEM 3060
# 93           Security and Privacy Concepts in the Wild    CS 5435
# 98   National Security Affairs / Preparation for Ac...  AIRS 4401
# 123                 Internet Law, Privacy and Security   LAW 6568
# 128  Practitioner's Overview of Securities Markets ...   AEM 3060
#
#                                            description credits  \
# 20   This course will impart a technical and social...       3
# 25   Focuses on fixed-income securities including c...       4
# 49   This course introduces students to privacy tec...     3-4
# 54   A broad overview of various aspects of the Fix...       1
# 93   This course will impart a technical and social...       3
# 98   This course is designed for college seniors an...       3
# 123  This is a survey course in Internet law, with ...       3
# 128  A broad overview of various aspects of the Fix...       1
#
#          instructor                                     syllabus  \
# 20         Juels, A                                  1 available
# 25         Bogan, V                                         none
# 49    Nissenbaum, H                                         none
# 54       Edwards, A                                  1 available
# 93         Juels, A                                  1 available
# 98         Heath, M                                         none
# 123  Grimmelmann, J                                  1 available
# 128      Edwards, A                                  1 available
#
#              university         term keyword
# 20   cornell university    Fall 2017  privac
# 25   cornell university    Fall 2017   secur
# 49   cornell university  Spring 2018  privac
# 54   cornell university  Spring 2018   secur
# 93   cornell university    Fall 2018  privac
# 98   cornell university    Fall 2018   secur
# 123  cornell university  Spring 2019  privac
# 128  cornell university  Spring 2019   secur

# %%
#loop through technical keyword list, extract relevant titles
for word in technical:
    df = cornell[cornell['title'].str.contains(word, flags = re.IGNORECASE)]
    df['keyword2'] = word
    
#join keyword cols
df["keyword"] = df["keyword"].map(str) + "," + df["keyword2"]
df = df.drop(columns="keyword2")

df
# Out:
# /Users/Shiying/.pyenv/versions/3.7.2/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Shiying/.pyenv/versions/3.7.2/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                                          title   dept_num  \
# 38  Gendering Religion, Science and Technology  AMST 2621
#
#                                           description credits      instructor  \
# 38  There are several "just-so stories" about scie...       4  Rock-Singer, C
#
#                                 syllabus          university         term  \
# 38                                  none  cornell university  Spring 2018
#
#              keyword
# 38  gender,technolog

# %% [markdown]
# NOTE: the above cell is likely not the best nor most simple way to execute this step! Feel free to take special liberties here. It's probably wise to pick out a few titles that you know should be returned manually, then check to see if the script is working as desired.

# %%
#combine dfs 
cornell = pd.concat([df, exceptions])
cornell
# Out:
#                                                  title   dept_num  \
# 38          Gendering Religion, Science and Technology  AMST 2621
# 20           Security and Privacy Concepts in the Wild    CS 5435
# 25                             Fixed-Income Securities   AEM 4260
# 49                          Privacy in the Digital Age    CS 5436
# 54   Practitioner's Overview of Securities Markets ...   AEM 3060
# 93           Security and Privacy Concepts in the Wild    CS 5435
# 98   National Security Affairs / Preparation for Ac...  AIRS 4401
# 123                 Internet Law, Privacy and Security   LAW 6568
# 128  Practitioner's Overview of Securities Markets ...   AEM 3060
#
#                                            description credits  \
# 38   There are several "just-so stories" about scie...       4
# 20   This course will impart a technical and social...       3
# 25   Focuses on fixed-income securities including c...       4
# 49   This course introduces students to privacy tec...     3-4
# 54   A broad overview of various aspects of the Fix...       1
# 93   This course will impart a technical and social...       3
# 98   This course is designed for college seniors an...       3
# 123  This is a survey course in Internet law, with ...       3
# 128  A broad overview of various aspects of the Fix...       1
#
#          instructor                                     syllabus  \
# 38   Rock-Singer, C                                         none
# 20         Juels, A                                  1 available
# 25         Bogan, V                                         none
# 49    Nissenbaum, H                                         none
# 54       Edwards, A                                  1 available
# 93         Juels, A                                  1 available
# 98         Heath, M                                         none
# 123  Grimmelmann, J                                  1 available
# 128      Edwards, A                                  1 available
#
#              university         term           keyword
# 38   cornell university  Spring 2018  gender,technolog
# 20   cornell university    Fall 2017            privac
# 25   cornell university    Fall 2017             secur
# 49   cornell university  Spring 2018            privac
# 54   cornell university  Spring 2018             secur
# 93   cornell university    Fall 2018            privac
# 98   cornell university    Fall 2018             secur
# 123  cornell university  Spring 2019            privac
# 128  cornell university  Spring 2019             secur

# %% [markdown]
# Lastly, we want to export our csv. Ideally, all csv files should be written to the courses directory in our repository.

# %%
#export as csv
cornell.to_csv('../courses/Texas A & M University-College Station.csv')
