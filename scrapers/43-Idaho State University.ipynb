# %% [markdown]
# ## Georgia Southern University Crawler

# %% [markdown]
# Imports.

# %%
import pandas as pd
import numpy as np
import re
import urllib.request #handles urls
import urllib.parse 
import linkGrabber #extracts urls
import json #encodes/decodes json 
import csv 
import requests #downloads a webpage to scrape
from bs4 import BeautifulSoup, NavigableString, Tag #beautifulsoup pulls data from HTML
import nltk #NLP tasks
from nltk import word_tokenize
from nltk.stem import PorterStemmer #removes word endings
stemmer = PorterStemmer()

# %% [markdown]
# Keyword preprocessing and url list of relevant catalog years; 2019-20 and 2018-19. Also a list of departments.

# %%
#keyword preprocessing
def preprocess(keyword):
    keyword = keyword.lower() #lowercase
    keyword = word_tokenize(keyword) #tokenize
    for word in keyword:
        keyword = stemmer.stem(word) #stem 
    return (keyword)

#course catalog URLs - 2 academic years 
urls = ['http://coursecat.isu.edu/undergraduate/allcourses/',
        'http://coursecat.isu.edu/previouscatalogs/2018-19/undergraduate/allcourses/']

#list of all the departments to search through 
departments = ['acad/','acct/','admt/','airm/','amst/',
               'anth/','arbc/','art/','acrr/','autm/',
               'biol/','psci/','bed/','ba/','bt/','cte/',
               'chem/','cfs/','chld/','chns/','ce/','cet/',
               'comm/','cmp/','csd/','cpar/','cmlt/','cadd/',
               'mach/','cs/','cosm/','coun/','daac/','danc/',
               'dent/','dms/','desl/','ntd/','dhs/','econ/',
               'educ/','elap/','ee/','eet/','ems/','emgt/',
               'eset/','engl/','enve/','fcs/','fin/','fsa/',
               'fren/','gemt/','geol/','germ/','glbl/','hca/',
               'he/','hit/','ho/','hphy/','hist/','hrd/','idep/',
               'info/','its/','inst/','is/','japn/','lang/',
               'latn/','lawe/','llib/','mgt/','mktg/','msth/',
               'math/','me/','ma/','mls/','msl/','muse/','musa/',
               'musi/','musc/','musp/','nse/','ne/','nurs/','ota/',
               'opt/','olp/','para/','parm/','phar/','ppra/','phtc/',
               'phil/','peac/','pe/','ptot/','pta/','pas/','phys/',
               'plap/','pols/','pnur/','pte/','psyc/','rs/','adrn/',
               'resp/','rcet/','russ/','scpy/','shos/','sowk/','soc/',
               'span/','sped/','stua/','tge/','thea/','hons/','us/',
               'uas/','weld/']

# %% [markdown]
# Creation of normative and technical keywords lists, the same as in example crawler.

# %%
#import keywords
keywords = pd.read_csv("keywords.csv")
technical = keywords[(keywords['Technical/Normative']=='T') & (keywords['Include']=='Y')].Keyword
normative = keywords[(keywords['Technical/Normative']=='N') & (keywords['Include']=='Y')].Keyword
normative = [preprocess(i) for i in normative]
technical = [preprocess(i) for i in technical] 

#replace keywords of interest
normative = [w.replace('privaci', 'privac') for w in normative]
normative = [w.replace('democraci', 'democra') for w in normative]
normative = [w.replace('equiti', 'equit') for w in normative]
normative = [w.replace('histori', 'histor') for w in normative]
normative = [w.replace('justice', 'justic') for w in normative]
normative = [w.replace('liberti', 'libert') for w in normative]
normative = [w.replace('philosophi', 'philosoph') for w in normative]
normative = [w.replace('societi', 'societ') for w in normative]
normative = [w.replace('polici', 'polic') for w in normative]

technical = [w.replace('ai', '^ai') for w in technical]
technical = [w.replace('cs', '^cs') for w in technical]
technical = [w.replace('ict', '^ict') for w in technical]
technical = [w.replace('ml', '^ml') for w in technical]
technical = [w.replace('nlp', '^nlp') for w in technical]

print(normative)
print(technical)
# Out:
# ['account', 'critic', 'democra', 'discrimin', 'equal', 'equit', 'ethic', 'fair', 'femin', 'gender', 'govern', 'histor', 'inequ', 'justic', 'law', 'legal', 'libert', 'moral', 'norm', 'philosoph', 'polit', 'power', 'privac', 'race', 'religi', 'respons', 'right', 'secur', 'social', 'societ', 'surveil', 'transpar', 'valu', 'polic']
# ['^ai', 'algorithm', 'analyt', 'intellig', 'automat', 'code', 'comput', '^cs', 'cyber', 'data', 'digit', '^ict', 'inform', 'intelligen', 'internet', 'machin', '^ml', 'process', '^nlp', 'platform', 'program', 'robot', 'softwar', 'system', 'technolog']

# %% [markdown]
# Extraction process for Georgia Southern University:
# 1. Loop through each years' catalog.
# 2. Loop through each of the departments' pages by concatenating the department code to the catalog url
# 3. On the department page, make a list of all the course titles, credits, and descriptions
# 4. Loop through all the keywords in the normative list and check to see if the keyword can be found in the course title
# 5. If the keyword is in the title, then assign every element of the data columns that can be located.
#
# Data columns are defined in the same way as below and have the same anatomy for each course:
# * The course title - in the title list, the string sequence after the last instance of \xa0: `title`
# * The department and course number - in the title list, the string sequence before the first instance of \xa0: `dept_num`
# * The course description - items in the description list: `description`
# * The number of credits for the course - items in the credit list: `credits`
# * The course instructor - school does not list in catalog: `instructor`
# * The link to the course syllabus (if applicable) - school does not list in catalog: `syllabus`
# * The university the course is extracted from - all from the same university: `university`
# * The term that the course is offered during (fall, spring, summer / year) - Only matched by year through url: `term`
# * The keyword that triggered the extraction (this is for auditing purposes): `keyword`

# %%
#init dfs
idaho = pd.DataFrame(columns=['title','dept_num','description','credits','instructor',
                                'syllabus','university','term','keyword'])
titles = []
dept_nums = []
descs = []
credit = []
profs = []
syllabi = []
uni = []
term = []     
keyword = []

# %% [markdown]
# The extraction process. The process to create the table is kept the same as the example crawler, just as a loop on it's own after all the titles, credits, etc. are all gathered.

# %%
#looping through each years catalog
for url in urls:
    #looping through all the departments pages to process individual course's information
    for dept in departments:
        page_link = url + dept
        page_response = requests.get(page_link)
        soup = BeautifulSoup(page_response.content, 'html.parser')
        courses = [p.get_text().split('\n') for p in soup.select(".courseblock")]
        for crs in courses:
            title = crs[1]
            for word in normative:
                if word in title.lower():
                    titles.append(title[title.find('  '):title.rfind(':')])
                    dept_nums.append(title[:title.find('  ')])
                    if(crs[3]==''): descs.append('No description available.')
                    else: descs.append(crs[3][:crs[3].rfind('.')])
                    credit.append(title[title.rfind('  '):len(title)-1])
                    profs.append('Not Listed')
                    syllabi.append('Not Listed')
                    uni.append('Idaho State University')
                    if(url=='http://coursecat.isu.edu/undergraduate/allcourses/'): 
                        if(len(crs[3][crs[3].rfind('.')+1:])>7): term.append('2019-20')
                        else: term.append('2019-20' + crs[3][crs[3].rfind('.')+1:])
                    elif(len(crs[3][crs[3].rfind('.')+1:])>7): term.append('2018-19')
                    else: term.append('2018-19' + crs[3][crs[3].rfind('.')+1:])
                    keyword.append(word)
            
for a,b,c,d,e,f,g,h,i in zip(titles,dept_nums,descs,credit,profs,syllabi,uni,term,keyword):
    idaho = idaho.append({'title': a, 
                              'dept_num': b,
                              'description': c,
                              'credits': d,
                              'instructor': e,
                              'syllabus': f,
                              'university': g,
                              'term': h,
                              'keyword': i}, ignore_index=True)

# %% [markdown]
# Post filtering of course. Code is identical to that of example crawler.

# %%
exceptions = idaho.loc[(idaho['keyword']=='privac') | (idaho['keyword'] =='secur')]
exceptions
# Out:
#                                           title    dept_num  \
# 58           Computer Security and Cryptography     CS 4420
# 59                  Secure Software Engineering     CS 4424
# 107                   Wireless Network Security   ESET 0282
# 108          Introduction to Network Security I  ESET 0282A
# 109         Introduction to Network Security II  ESET 0282B
# 110          Information System Security Design   ESET 0283
# 113                   Critical Network Security   ESET 0286
# 114    Cyber Physical Systems Security Capstone   ESET 0289
# 200      Systems Security for Senior Management   INFO 4412
# 201             Systems Security Administration   INFO 4413
# 202                 Systems Security Management   INFO 4414
# 204      Secure Software Life Cycle Development   INFO 4484
# 205                               Cybersecurity    ITS 0165
# 207                            Securing the LAN    ITS 0240
# 434          Computer Security and Cryptography     CS 4420
# 482                   Wireless Network Security   ESET 0282
# 483          Introduction to Network Security I  ESET 0282A
# 484         Introduction to Network Security II  ESET 0282B
# 485          Information System Security Design   ESET 0283
# 488                   Critical Network Security   ESET 0286
# 489    Cyber Physical Systems Security Capstone   ESET 0289
# 572      Systems Security for Senior Management   INFO 4412
# 573             Systems Security Administration   INFO 4413
# 574                 Systems Security Management   INFO 4414
# 576      Secure Software Life Cycle Development   INFO 4484
# 577                               Cybersecurity    ITS 0165
# 579                            Securing the LAN    ITS 0240
#
#                                            description               credits  \
# 58   Public key and private key cryptography, key d...      3 semester hours
# 59   Introduction to the Secure Software Developmen...      3 semester hours
# 107  Overview of wireless networks with a focus on ...      3 semester hours
# 108  Facilitates competence in networking fundament...       1 semester hour
# 109  Continuation of ESET 0282A. Through a hands on...      2 semester hours
# 110  Examination of the design methods and techniqu...      3 semester hours
# 113  Comprehensive review and analysis of current a...      3 semester hours
# 114  Promotes professional development through part...      3 semester hours
# 200  Review of system architecture, system security...    1-3 semester hours
# 201  Outlines the basic principles of systems secur...    1-3 semester hours
# 202  Establishes a framework for managing both syst...    1-3 semester hours
# 204  In today's interconnected world, security must...      3 semester hours
# 205  An introduction to Cybersecurity that explores...      3 semester hours
# 207  Design and implement security solutions for LA...      4 semester hours
# 434  Public key and private key cryptopgraphy, key ...      3 semester hours
# 482  Overview of wireless networks with a focus on ...      3 semester hours
# 483  Facilitates competence in networking fundament...       1 semester hour
# 484  Continuation of ESET 0282A. Through a hands on...      2 semester hours
# 485  Examination of the design methods and techniqu...      3 semester hours
# 488  Comprehensive review and analysis of current a...      3 semester hours
# 489  Promotes professional development through part...      3 semester hours
# 572  Review of system architecture, system security...    1-3 semester hours
# 573  Outlines the basic principles of systems secur...    1-3 semester hours
# 574  Establishes a framework for managing both syst...    1-3 semester hours
# 576  In today's interconnected world, security must...      3 semester hours
# 577  An introduction to Cybersecurity that explores...      3 semester hours
# 579  Design and implement security solutions for LA...      4 semester hours
#
#      instructor    syllabus              university           term keyword
# 58   Not Listed  Not Listed  Idaho State University      2019-20 D   secur
# 59   Not Listed  Not Listed  Idaho State University      2019-20 D   secur
# 107  Not Listed  Not Listed  Idaho State University  2019-20  S, D   secur
# 108  Not Listed  Not Listed  Idaho State University   2019-20 F, D   secur
# 109  Not Listed  Not Listed  Idaho State University   2019-20 F, D   secur
# 110  Not Listed  Not Listed  Idaho State University  2019-20  F, D   secur
# 113  Not Listed  Not Listed  Idaho State University   2019-20 S, D   secur
# 114  Not Listed  Not Listed  Idaho State University   2019-20 F, S   secur
# 200  Not Listed  Not Listed  Idaho State University     2019-20  D   secur
# 201  Not Listed  Not Listed  Idaho State University     2019-20  D   secur
# 202  Not Listed  Not Listed  Idaho State University     2019-20  D   secur
# 204  Not Listed  Not Listed  Idaho State University     2019-20  D   secur
# 205  Not Listed  Not Listed  Idaho State University        2019-20   secur
# 207  Not Listed  Not Listed  Idaho State University  2019-20  F, S   secur
# 434  Not Listed  Not Listed  Idaho State University      2018-19 D   secur
# 482  Not Listed  Not Listed  Idaho State University  2018-19  S, D   secur
# 483  Not Listed  Not Listed  Idaho State University   2018-19 F, D   secur
# 484  Not Listed  Not Listed  Idaho State University   2018-19 F, D   secur
# 485  Not Listed  Not Listed  Idaho State University  2018-19  F, D   secur
# 488  Not Listed  Not Listed  Idaho State University   2018-19 S, D   secur
# 489  Not Listed  Not Listed  Idaho State University   2018-19 F, S   secur
# 572  Not Listed  Not Listed  Idaho State University     2018-19  D   secur
# 573  Not Listed  Not Listed  Idaho State University     2018-19  D   secur
# 574  Not Listed  Not Listed  Idaho State University     2018-19  D   secur
# 576  Not Listed  Not Listed  Idaho State University     2018-19  D   secur
# 577  Not Listed  Not Listed  Idaho State University        2018-19   secur
# 579  Not Listed  Not Listed  Idaho State University  2018-19  F, S   secur

# %%
#loop through technical keyword list, extract relevant titles
for word in technical:
    df = idaho[idaho['title'].str.contains(word, flags = re.IGNORECASE)]
    df['keyword2'] = word
    
#join keyword cols
df["keyword"] = df["keyword"].map(str) + "," + df["keyword2"]
df = df.drop(columns="keyword2")

df
# Out:
# C:\Users\Beverly\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Beverly\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                               title   dept_num  \
# 245           Law Office Technology  PARA 0119
# 373    Applied Ethics in Technology   TGE 1257
# 616           Law Office Technology  PARA 0119
# 742    Applied Ethics in Technology   TGE 1257
#
#                                            description             credits  \
# 245  Students will learn advanced and specialized c...    2 semester hours
# 373  An introduction to the study of ethics and con...    3 semester hours
# 616  Students will learn advanced and specialized c...    2 semester hours
# 742  An introduction to the study of ethics and con...    3 semester hours
#
#      instructor    syllabus              university        term  \
# 245  Not Listed  Not Listed  Idaho State University  2019-20  F
# 373  Not Listed  Not Listed  Idaho State University  2019-20  D
# 616  Not Listed  Not Listed  Idaho State University  2018-19  F
# 742  Not Listed  Not Listed  Idaho State University  2018-19  D
#
#              keyword
# 245    law,technolog
# 373  ethic,technolog
# 616    law,technolog
# 742  ethic,technolog

# %%
#combine dfs 
idaho = pd.concat([df, exceptions])
idaho
# Out:
#                                           title    dept_num  \
# 245                       Law Office Technology   PARA 0119
# 373                Applied Ethics in Technology    TGE 1257
# 616                       Law Office Technology   PARA 0119
# 742                Applied Ethics in Technology    TGE 1257
# 58           Computer Security and Cryptography     CS 4420
# 59                  Secure Software Engineering     CS 4424
# 107                   Wireless Network Security   ESET 0282
# 108          Introduction to Network Security I  ESET 0282A
# 109         Introduction to Network Security II  ESET 0282B
# 110          Information System Security Design   ESET 0283
# 113                   Critical Network Security   ESET 0286
# 114    Cyber Physical Systems Security Capstone   ESET 0289
# 200      Systems Security for Senior Management   INFO 4412
# 201             Systems Security Administration   INFO 4413
# 202                 Systems Security Management   INFO 4414
# 204      Secure Software Life Cycle Development   INFO 4484
# 205                               Cybersecurity    ITS 0165
# 207                            Securing the LAN    ITS 0240
# 434          Computer Security and Cryptography     CS 4420
# 482                   Wireless Network Security   ESET 0282
# 483          Introduction to Network Security I  ESET 0282A
# 484         Introduction to Network Security II  ESET 0282B
# 485          Information System Security Design   ESET 0283
# 488                   Critical Network Security   ESET 0286
# 489    Cyber Physical Systems Security Capstone   ESET 0289
# 572      Systems Security for Senior Management   INFO 4412
# 573             Systems Security Administration   INFO 4413
# 574                 Systems Security Management   INFO 4414
# 576      Secure Software Life Cycle Development   INFO 4484
# 577                               Cybersecurity    ITS 0165
# 579                            Securing the LAN    ITS 0240
#
#                                            description               credits  \
# 245  Students will learn advanced and specialized c...      2 semester hours
# 373  An introduction to the study of ethics and con...      3 semester hours
# 616  Students will learn advanced and specialized c...      2 semester hours
# 742  An introduction to the study of ethics and con...      3 semester hours
# 58   Public key and private key cryptography, key d...      3 semester hours
# 59   Introduction to the Secure Software Developmen...      3 semester hours
# 107  Overview of wireless networks with a focus on ...      3 semester hours
# 108  Facilitates competence in networking fundament...       1 semester hour
# 109  Continuation of ESET 0282A. Through a hands on...      2 semester hours
# 110  Examination of the design methods and techniqu...      3 semester hours
# 113  Comprehensive review and analysis of current a...      3 semester hours
# 114  Promotes professional development through part...      3 semester hours
# 200  Review of system architecture, system security...    1-3 semester hours
# 201  Outlines the basic principles of systems secur...    1-3 semester hours
# 202  Establishes a framework for managing both syst...    1-3 semester hours
# 204  In today's interconnected world, security must...      3 semester hours
# 205  An introduction to Cybersecurity that explores...      3 semester hours
# 207  Design and implement security solutions for LA...      4 semester hours
# 434  Public key and private key cryptopgraphy, key ...      3 semester hours
# 482  Overview of wireless networks with a focus on ...      3 semester hours
# 483  Facilitates competence in networking fundament...       1 semester hour
# 484  Continuation of ESET 0282A. Through a hands on...      2 semester hours
# 485  Examination of the design methods and techniqu...      3 semester hours
# 488  Comprehensive review and analysis of current a...      3 semester hours
# 489  Promotes professional development through part...      3 semester hours
# 572  Review of system architecture, system security...    1-3 semester hours
# 573  Outlines the basic principles of systems secur...    1-3 semester hours
# 574  Establishes a framework for managing both syst...    1-3 semester hours
# 576  In today's interconnected world, security must...      3 semester hours
# 577  An introduction to Cybersecurity that explores...      3 semester hours
# 579  Design and implement security solutions for LA...      4 semester hours
#
#      instructor    syllabus              university           term  \
# 245  Not Listed  Not Listed  Idaho State University     2019-20  F
# 373  Not Listed  Not Listed  Idaho State University     2019-20  D
# 616  Not Listed  Not Listed  Idaho State University     2018-19  F
# 742  Not Listed  Not Listed  Idaho State University     2018-19  D
# 58   Not Listed  Not Listed  Idaho State University      2019-20 D
# 59   Not Listed  Not Listed  Idaho State University      2019-20 D
# 107  Not Listed  Not Listed  Idaho State University  2019-20  S, D
# 108  Not Listed  Not Listed  Idaho State University   2019-20 F, D
# 109  Not Listed  Not Listed  Idaho State University   2019-20 F, D
# 110  Not Listed  Not Listed  Idaho State University  2019-20  F, D
# 113  Not Listed  Not Listed  Idaho State University   2019-20 S, D
# 114  Not Listed  Not Listed  Idaho State University   2019-20 F, S
# 200  Not Listed  Not Listed  Idaho State University     2019-20  D
# 201  Not Listed  Not Listed  Idaho State University     2019-20  D
# 202  Not Listed  Not Listed  Idaho State University     2019-20  D
# 204  Not Listed  Not Listed  Idaho State University     2019-20  D
# 205  Not Listed  Not Listed  Idaho State University        2019-20
# 207  Not Listed  Not Listed  Idaho State University  2019-20  F, S
# 434  Not Listed  Not Listed  Idaho State University      2018-19 D
# 482  Not Listed  Not Listed  Idaho State University  2018-19  S, D
# 483  Not Listed  Not Listed  Idaho State University   2018-19 F, D
# 484  Not Listed  Not Listed  Idaho State University   2018-19 F, D
# 485  Not Listed  Not Listed  Idaho State University  2018-19  F, D
# 488  Not Listed  Not Listed  Idaho State University   2018-19 S, D
# 489  Not Listed  Not Listed  Idaho State University   2018-19 F, S
# 572  Not Listed  Not Listed  Idaho State University     2018-19  D
# 573  Not Listed  Not Listed  Idaho State University     2018-19  D
# 574  Not Listed  Not Listed  Idaho State University     2018-19  D
# 576  Not Listed  Not Listed  Idaho State University     2018-19  D
# 577  Not Listed  Not Listed  Idaho State University        2018-19
# 579  Not Listed  Not Listed  Idaho State University  2018-19  F, S
#
#              keyword
# 245    law,technolog
# 373  ethic,technolog
# 616    law,technolog
# 742  ethic,technolog
# 58             secur
# 59             secur
# 107            secur
# 108            secur
# 109            secur
# 110            secur
# 113            secur
# 114            secur
# 200            secur
# 201            secur
# 202            secur
# 204            secur
# 205            secur
# 207            secur
# 434            secur
# 482            secur
# 483            secur
# 484            secur
# 485            secur
# 488            secur
# 489            secur
# 572            secur
# 573            secur
# 574            secur
# 576            secur
# 577            secur
# 579            secur

# %% [markdown]
# Exporting of code to csv.

# %%
#export as csv
idaho.to_csv('43-Idaho State University.csv')
