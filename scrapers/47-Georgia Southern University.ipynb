# %% [markdown]
# ## Georgia Southern University Crawler

# %% [markdown]
# Imports.

# %%
import pandas as pd
import numpy as np
import re
import urllib.request #handles urls
import urllib.parse 
import linkGrabber #extracts urls
import json #encodes/decodes json 
import csv 
import requests #downloads a webpage to scrape
from bs4 import BeautifulSoup, NavigableString, Tag #beautifulsoup pulls data from HTML
import nltk #NLP tasks
from nltk import word_tokenize
from nltk.stem import PorterStemmer #removes word endings
stemmer = PorterStemmer()

# %% [markdown]
# Keyword preprocessing and url list of relevant catalog years; 2019-20 and 2018-19. Also a list of departments.

# %%
#keyword preprocessing
def preprocess(keyword):
    keyword = keyword.lower() #lowercase
    keyword = word_tokenize(keyword) #tokenize
    for word in keyword:
        keyword = stemmer.stem(word) #stem 
    return (keyword)

#course catalog URLs - 2 academic years 
urls = ['https://catalog.georgiasouthern.edu/academics/course-descriptions/',
        'https://catalog.georgiasouthern.edu/archive/2018-2019/academics/course-descriptions/']

#list of all the departments to search through 
departments = ['aast/','acct/','aded/','afas/','anth/',
               'apan/','arab/','arch/','art/','artg/',
               'arth/','arts/','astr/','bchm/','biol/',
               'bios/','bkin/','busa/','ceng/','chbe/',
               'chem/','chfd/','chin/','cied/','cism/',
               'coed/','cohe/','coml/','comm/','coms/',
               'coop/','coun/','crju/','csci/','csds/',
               'cvis/','ddts/','ece/','eceg/','econ/',
               'edat/','edci/','edet/','edld/','edms/',
               'edmt/','edrd/','edsc/','educ/','eduf',
               'edur/','eele/','eeng/','eexe/','egc/',
               'elem/','emba/','engl/','engr/','envh/',
               'envs/','epid/','eprs/','epsf/','epy/',
               'esed/','esl/','espy/','ethc/','euro/',
               'facs/','film/','finc/','fmad/','forl',
               'foun/','frct/','frec/','fren/','frer/',
               'frit/','frlt/','frms/','fye/','gcm/',
               'geog/','geol/','geph/','gero/','gnst/',
               'grmn/','gsou/','gsu/','gwst/','hadm/',
               'hist/','hitc/','hlpr/','hlth/','hnrm/',
               'hons/','hsca/','hscc/','hscf/','hscg/',
               'hscp/','hspm/','humn/','ids/','inds/',
               'ints/','ipse/','irsh/','isci/','it/',
               'itec/','itw/','japn/','kins/','last/',
               'latn/','lead/','lesp/','ling/','logt/',
               'lscm/','lstd/','lwso/','maed/','math/',
               'medt/','meng/','metr/','mfge/','mged/',
               'mgms/','mgnt/','mgse/','mhsa/','mktg/',
               'mmfp/','mmj/','msci/','msed/','musa/',
               'musc/','muse/','nsci/','ntfs/','nucm/',
               'nurs/','ocea/','ontl/','oscm/','pbad/',
               'pbhs/','pbis/','peat/','pebc/','peci/',
               'peec/','pehm/','phil/','phld/','phsc/',
               'phth/','phys/','pols/','prca/','psyc/',
               'psyg/','pubh/','radr/','rads/','rdsc/',
               'read/','recr/','reli/','rels/','resp/',
               'rhab/','rlc/','rthr/','sabr/','sced/',
               'scie/','seac/','segc/','serd/','slpa/',
               'smed/','smgt/','soar/','soci/','sono/',
               'span/','sped/','ssci/','stat/','sust/',
               'tcgt/','tcld/','tcm/','tfg/','tget/',
               'thea/','tmae/','tmfg/','tsec/','tsle/',
               'wbit/','wbus/','wgss/','wgst/','wlst/',
               'wmac/','wmba/','writ/','xreg/']

# %% [markdown]
# Creation of normative and technical keywords lists, the same as in example crawler.

# %%
#import keywords
keywords = pd.read_csv("keywords.csv")
technical = keywords[(keywords['Technical/Normative']=='T') & (keywords['Include']=='Y')].Keyword
normative = keywords[(keywords['Technical/Normative']=='N') & (keywords['Include']=='Y')].Keyword
normative = [preprocess(i) for i in normative]
technical = [preprocess(i) for i in technical] 

#replace keywords of interest
normative = [w.replace('privaci', 'privac') for w in normative]
normative = [w.replace('democraci', 'democra') for w in normative]
normative = [w.replace('equiti', 'equit') for w in normative]
normative = [w.replace('histori', 'histor') for w in normative]
normative = [w.replace('justice', 'justic') for w in normative]
normative = [w.replace('liberti', 'libert') for w in normative]
normative = [w.replace('philosophi', 'philosoph') for w in normative]
normative = [w.replace('societi', 'societ') for w in normative]
normative = [w.replace('polici', 'polic') for w in normative]

technical = [w.replace('ai', '^ai') for w in technical]
technical = [w.replace('cs', '^cs') for w in technical]
technical = [w.replace('ict', '^ict') for w in technical]
technical = [w.replace('ml', '^ml') for w in technical]
technical = [w.replace('nlp', '^nlp') for w in technical]

print(normative)
print(technical)
# Out:
# ['account', 'critic', 'democra', 'discrimin', 'equal', 'equit', 'ethic', 'fair', 'femin', 'gender', 'govern', 'histor', 'inequ', 'justic', 'law', 'legal', 'libert', 'moral', 'norm', 'philosoph', 'polit', 'power', 'privac', 'race', 'religi', 'respons', 'right', 'secur', 'social', 'societ', 'surveil', 'transpar', 'valu', 'polic']
# ['^ai', 'algorithm', 'analyt', 'intellig', 'automat', 'code', 'comput', '^cs', 'cyber', 'data', 'digit', '^ict', 'inform', 'intelligen', 'internet', 'machin', '^ml', 'process', '^nlp', 'platform', 'program', 'robot', 'softwar', 'system', 'technolog']

# %% [markdown]
# Extraction process for Georgia Southern University:
# 1. Loop through each years' catalog.
# 2. Loop through each of the departments' pages by concatenating the department code to the catalog url
# 3. On the department page, make a list of all the course titles, credits, and descriptions
# 4. Loop through all the keywords in the normative list and check to see if the keyword can be found in the course title
# 5. If the keyword is in the title, then assign every element of the data columns that can be located.
#
# Data columns are defined in the same way as below and have the same anatomy for each course:
# * The course title - in the title list, the string sequence after the last instance of \xa0: `title`
# * The department and course number - in the title list, the string sequence before the first instance of \xa0: `dept_num`
# * The course description - items in the description list: `description`
# * The number of credits for the course - items in the credit list: `credits`
# * The course instructor - school does not list in catalog: `instructor`
# * The link to the course syllabus (if applicable) - school does not list in catalog: `syllabus`
# * The university the course is extracted from - all from the same university: `university`
# * The term that the course is offered during (fall, spring, summer / year) - Only matched by year through url: `term`
# * The keyword that triggered the extraction (this is for auditing purposes): `keyword`

# %%
#init dfs
georgia = pd.DataFrame(columns=['title','dept_num','description','credits','instructor',
                                'syllabus','university','term','keyword'])
titles = []
dept_nums = []
descs = []
credit = []
profs = []
syllabi = []
uni = []
term = []     
keyword = []

# %% [markdown]
# The extraction process. The process to create the table is kept the same as the example crawler, just as a loop on it's own after all the titles, credits, etc. are all gathered.

# %%
#looping through each years catalog
for url in urls:
    #looping through all the departments pages to process individual course's information
    for dept in departments:
        page_link = url + dept
        page_response = requests.get(page_link)
        soup = BeautifulSoup(page_response.content, 'html.parser')
        courses = [p.get_text() for p in soup.select(".courseblocktitle")]
        hours = [p.get_text() for p in soup.select(".noindent.courseblockhours")]
        descrip = [p.get_text() for p in soup.select(".courseblockdesc")]
        for crs in range(len(courses)):
            title = courses[crs]
            for word in normative:
                if word in title.lower():
                    titles.append(title[title.rfind('\xa0')+1:])
                    dept_nums.append(title[:title.rfind('\xa0')-1])
                    if(descrip[crs]==''): descs.append('No description available.')
                    else: descs.append(descrip[crs][descrip[crs].find('\n')+1:])
                    credit.append(hours[crs])
                    profs.append('Not Listed')
                    syllabi.append('Not Listed')
                    uni.append('Georgia Southern University')
                    if(url=='https://catalog.georgiasouthern.edu/academics/course-descriptions/'): 
                        term.append('2019-20')
                    else: term.append('2018-19')
                    keyword.append(word)
            
for a,b,c,d,e,f,g,h,i in zip(titles,dept_nums,descs,credit,profs,syllabi,uni,term,keyword):
    georgia = georgia.append({'title': a, 
                              'dept_num': b,
                              'description': c,
                              'credits': d,
                              'instructor': e,
                              'syllabus': f,
                              'university': g,
                              'term': h,
                              'keyword': i}, ignore_index=True)

# %% [markdown]
# Post filtering of course. Code is identical to that of example crawler.

# %%
exceptions = georgia.loc[(georgia['keyword']=='privac') | (georgia['keyword'] =='secur')]
exceptions
# Out:
#                                                   title      dept_num  \
# 79               Enterprise Infrastructure and Security   CISM   3134
# 80     Principles of Enterprise Information Systems ...   CISM   3331
# 120                      Indust, Commer & Private Secur   CRJU   3220
# 133                         Issues in Homeland Security   CRJU   3931
# 163                 Software Security and Secure Coding   CSCI   5380
# 164                                   Computer Security   CSCI   5431
# 165                                Computer Security \n  CSCI   5431G
# 166                 Software Security and Secure Coding   CSCI   7380
# 167                          Data and Database Security   CSCI   7433
# 169                       Network and Computer Security   CSCI   7536
# 170                          Advanced Computer Security   CSCI   7710
# 216    Cybersecurity for Networked Electrical and El...   EENG   5538
# 217    Cybersecurity for Networked Electrical and El...  EENG   5538G
# 261                             Fixed Income Securities   FINC   4150
# 262                                   Security Analysis   FINC   4232
# 421                    International Security Affairs\n   INTS   3430
# 422                                Global Food Security   INTS   3536
# 431                      Introduction to Cyber Security     IT   2531
# 432        Fundamentals of Information Systems Security     IT   3530
# 433                                    Network Security     IT   4336
# 435                Web and Mobile Security Fundamentals     IT   5233
# 436                Web and Mobile Security Fundamentals    IT   5233G
# 437                       Network Security Fundamentals     IT   5434
# 438                       Network Security Fundamentals    IT   5434G
# 440        Digital Security and Forensics Investigation     IT   7133
# 443                      Introduction to Cyber Security    ITW   2531
# 444        Fundamentals of Information Systems Security    ITW   3530
# 445                                    Network Security    ITW   4336
# 644                             Asian Regional Security   POLS   4240
# 645             Intelligence & National Security Policy   POLS   4270
# ...                                                 ...           ...
# 925    Principles of Enterprise Information Systems ...   CISM   3331
# 965                      Indust, Commer & Private Secur   CRJU   3220
# 978                         Issues in Homeland Security   CRJU   3931
# 1008                Software Security and Secure Coding   CSCI   5380
# 1009                                  Computer Security   CSCI   5431
# 1010                               Computer Security \n  CSCI   5431G
# 1011                Software Security and Secure Coding   CSCI   7380
# 1012                         Data and Database Security   CSCI   7433
# 1014                      Network and Computer Security   CSCI   7536
# 1015                         Advanced Computer Security   CSCI   7710
# 1061   Cybersecurity for Networked Electrical and El...   EENG   5538
# 1062   Cybersecurity for Networked Electrical and El...  EENG   5538G
# 1102                            Fixed Income Securities   FINC   4150
# 1103                                  Security Analysis   FINC   4232
# 1255                   International Security Affairs\n   INTS   3430
# 1256                               Global Food Security   INTS   3536
# 1265                     Introduction to Cyber Security     IT   2531
# 1266       Fundamentals of Information Systems Security     IT   3530
# 1267                                   Network Security     IT   4336
# 1269               Web and Mobile Security Fundamentals     IT   5233
# 1270               Web and Mobile Security Fundamentals    IT   5233G
# 1271                      Network Security Fundamentals     IT   5434
# 1272                      Network Security Fundamentals    IT   5434G
# 1274       Digital Security and Forensics Investigation     IT   7133
# 1468                            Asian Regional Security   POLS   4240
# 1469            Intelligence & National Security Policy   POLS   4270
# 1479          National Security of the Developing South   POLS   4510
# 1486            Politics and Security in Southwest Asia   POLS   4570
# 1625                                Network Security \n    TFG   7533
# 1631                               Information Security   WBIT   4520
#
#                                             description  \
# 79    An overview of the technology and management o...
# 80    An introduction to the various policy, adminis...
# 120    History, development, and analysis of private...
# 133   Explores the legal, practical, and ethical cha...
# 163   This course covers methodological framework fo...
# 164   Computer security theory and practice fundamen...
# 165   Computer security theory and practice fundamen...
# 166   This course covers methodological framework fo...
# 167   This  course  covers  data protection  approac...
# 169   An overview of the fundamentals of network and...
# 170   Theory and practice of computer security. Topi...
# 216   This course is designed to introduce emerging ...
# 217   This course is designed to introduce emerging ...
# 261   Five major debt markets (corporate, government...
# 262   This course examines some of the key assumptio...
# 421   Provides an examination of an array of interna...
# 422   This course explores the histories, ideas and ...
# 431   This course teaches the fundamental concepts a...
# 432   Current standards and best practice in informa...
# 433   Concepts of network security, including: count...
# 435   Cybersecurity is a cornerstone of web-based so...
# 436   Cybersecurity is a cornerstone of web-based so...
# 437   This course is intended to serve the needs of ...
# 438   This course is intended to serve the needs of ...
# 440   This course explores the logical weapons and t...
# 443   This course teaches the fundamental concepts a...
# 444   Current standards and best practice in informa...
# 445   Concepts of network security, including: count...
# 644    Applies international relations theory and co...
# 645   An examination of the roles played by the pres...
# ...                                                 ...
# 925   An introduction to the various policy, adminis...
# 965    History, development, and analysis of private...
# 978   Explores the legal, practical, and ethical cha...
# 1008  This course covers methodological framework fo...
# 1009  Computer security theory and practice fundamen...
# 1010  Computer security theory and practice fundamen...
# 1011  This course covers methodological framework fo...
# 1012  This  course  covers  data protection  approac...
# 1014  An overview of the fundamentals of network and...
# 1015  Theory and practice of computer security. Topi...
# 1061  This course is designed to introduce emerging ...
# 1062  This course is designed to introduce emerging ...
# 1102  Five major debt markets (corporate, government...
# 1103  This course examines some of the key assumptio...
# 1255  Provides an examination of an array of interna...
# 1256  This course explores the histories, ideas and ...
# 1265  This course teaches the fundamental concepts a...
# 1266  Current standards and best practice in informa...
# 1267  Concepts of network security, including: count...
# 1269  Cybersecurity is a cornerstone of web-based so...
# 1270  Cybersecurity is a cornerstone of web-based so...
# 1271  This course is intended to serve the needs of ...
# 1272  This course is intended to serve the needs of ...
# 1274  This course explores the logical weapons and t...
# 1468   Applies international relations theory and co...
# 1469  An examination of the roles played by the pres...
# 1479  Examination of the role, behavior and perspect...
# 1486  An in-depth understanding of the political and...
# 1625  This course provides an in-depth study of netw...
# 1631  This course is an introduction to information ...
#
#                                                 credits  instructor  \
# 79    3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
#
# 120                      Indust, Commer & Private Secur   CRJU   3220
# 133                         Issues in Homeland Security   CRJU   3931
# 163                 Software Security and Secure Coding   CSCI   5380
# 164                                   Computer Security   CSCI   5431
# 165                                Computer Security \n  CSCI   5431G
# 166                 Software Security and Secure Coding   CSCI   7380
# 167                          Data and Database Security   CSCI   7433
# 169                       Network and Computer Security   CSCI   7536
# 170                          Advanced Computer Security   CSCI   7710
# 216    Cybersecurity for Networked Electrical and El...   EENG   5538
# 217    Cybersecurity for Networked Electrical and El...  EENG   5538G
# 261                             Fixed Income Securities   FINC   4150
# 262                                   Security Analysis   FINC   4232
# 421                    International Security Affairs\n   INTS   3430
# 422                                Global Food Security   INTS   3536
# 431                      Introduction to Cyber Security     IT   2531
# 432        Fundamentals of Information Systems Security     IT   3530
# 433                                    Network Security     IT   4336
# 435                Web and Mobile Security Fundamentals     IT   5233
# 436                Web and Mobile Security Fundamentals    IT   5233G
# 437                       Network Security Fundamentals     IT   5434
# 438                       Network Security Fundamentals    IT   5434G
# ...                                                 ...           ...
# 925    Principles of Enterprise Information Systems ...   CISM   3331
# 965                      Indust, Commer & Private Secur   CRJU   3220
# 978                         Issues in Homeland Security   CRJU   3931
# 1008                Software Security and Secure Coding   CSCI   5380
# 1009                                  Computer Security   CSCI   5431
# 1010                               Computer Security \n  CSCI   5431G
# 1011                Software Security and Secure Coding   CSCI   7380
# 1012                         Data and Database Security   CSCI   7433
# 1014                      Network and Computer Security   CSCI   7536
# 1015                         Advanced Computer Security   CSCI   7710
# 1061   Cybersecurity for Networked Electrical and El...   EENG   5538
# 1062   Cybersecurity for Networked Electrical and El...  EENG   5538G
# 1102                            Fixed Income Securities   FINC   4150
# 1103                                  Security Analysis   FINC   4232
# 1255                   International Security Affairs\n   INTS   3430
# 1256                               Global Food Security   INTS   3536
# 1265                     Introduction to Cyber Security     IT   2531
# 1266       Fundamentals of Information Systems Security     IT   3530
# 1267                                   Network Security     IT   4336
# 1269               Web and Mobile Security Fundamentals     IT   5233
# 1270               Web and Mobile Security Fundamentals    IT   5233G
# 1271                      Network Security Fundamentals     IT   5434
# 1272                      Network Security Fundamentals    IT   5434G
# 1274       Digital Security and Forensics Investigation     IT   7133
# 1468                            Asian Regional Security   POLS   4240
# 1469            Intelligence & National Security Policy   POLS   4270
# 1479          National Security of the Developing South   POLS   4510
# 1486            Politics and Security in Southwest Asia   POLS   4570
# 1625                                Network Security \n    TFG   7533
# 1631                               Information Security   WBIT   4520
#
#                                             description  \
# 251   The purpose of this course is to introduce the...
# 560    A philisophical exploration of the formative ...
# 561    A philisophical exploration of the formative ...
# 1092  The purpose of this course is to introduce the...
# 1386   A philisophical exploration of the formative ...
# 1387   A philisophical exploration of the formative ...
# 79    An overview of the technology and management o...
# 80    An introduction to the various policy, adminis...
# 120    History, development, and analysis of private...
# 133   Explores the legal, practical, and ethical cha...
# 163   This course covers methodological framework fo...
# 164   Computer security theory and practice fundamen...
# 165   Computer security theory and practice fundamen...
# 166   This course covers methodological framework fo...
# 167   This  course  covers  data protection  approac...
# 169   An overview of the fundamentals of network and...
# 170   Theory and practice of computer security. Topi...
# 216   This course is designed to introduce emerging ...
# 217   This course is designed to introduce emerging ...
# 261   Five major debt markets (corporate, government...
# 262   This course examines some of the key assumptio...
# 421   Provides an examination of an array of interna...
# 422   This course explores the histories, ideas and ...
# 431   This course teaches the fundamental concepts a...
# 432   Current standards and best practice in informa...
# 433   Concepts of network security, including: count...
# 435   Cybersecurity is a cornerstone of web-based so...
# 436   Cybersecurity is a cornerstone of web-based so...
# 437   This course is intended to serve the needs of ...
# 438   This course is intended to serve the needs of ...
# ...                                                 ...
# 925   An introduction to the various policy, adminis...
# 965    History, development, and analysis of private...
# 978   Explores the legal, practical, and ethical cha...
# 1008  This course covers methodological framework fo...
# 1009  Computer security theory and practice fundamen...
# 1010  Computer security theory and practice fundamen...
# 1011  This course covers methodological framework fo...
# 1012  This  course  covers  data protection  approac...
# 1014  An overview of the fundamentals of network and...
# 1015  Theory and practice of computer security. Topi...
# 1061  This course is designed to introduce emerging ...
# 1062  This course is designed to introduce emerging ...
# 1102  Five major debt markets (corporate, government...
# 1103  This course examines some of the key assumptio...
# 1255  Provides an examination of an array of interna...
# 1256  This course explores the histories, ideas and ...
# 1265  This course teaches the fundamental concepts a...
# 1266  Current standards and best practice in informa...
# 1267  Concepts of network security, including: count...
# 1269  Cybersecurity is a cornerstone of web-based so...
# 1270  Cybersecurity is a cornerstone of web-based so...
# 1271  This course is intended to serve the needs of ...
# 1272  This course is intended to serve the needs of ...
# 1274  This course explores the logical weapons and t...
# 1468   Applies international relations theory and co...
# 1469  An examination of the roles played by the pres...
# 1479  Examination of the role, behavior and perspect...
# 1486  An in-depth understanding of the political and...
# 1625  This course provides an in-depth study of netw...
# 1631  This course is an introduction to information ...
#
#                                                 credits  instructor  \
# 251   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 560   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 561   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1092  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1386  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1387  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 79    3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 80    3 Credit Hours.   0,2 Lecture Hours.   0,1 Lab...  Not Listed
# 120   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 133   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 163   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 164   3 Credit Hours.   0,2 Lecture Hours.   0,2 Lab...  Not Listed
# 165   3 Credit Hours.   2 Lecture Hours.   2 Lab Hours.  Not Listed
# 166   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 167   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 169   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 170   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 216   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 217   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 261   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 262   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 421   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 422   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 431   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 432   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 433   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 435   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 436   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 437   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 438   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# ...                                                 ...         ...
# 925   3 Credit Hours.   0,2 Lecture Hours.   0,1 Lab...  Not Listed
# 965   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 978   3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1008  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1009  3 Credit Hours.   0,2 Lecture Hours.   0,2 Lab...  Not Listed
# 1010  3 Credit Hours.   2 Lecture Hours.   2 Lab Hours.  Not Listed
# 1011  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1012  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1014  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1015  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1061  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1062  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1102  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1103  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1255  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1256  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1265  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1266  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1267  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1269  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1270  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1271  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1272  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1274  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1468  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1469  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1479  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1486  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1625  3 Credit Hours.   3 Lecture Hours.   0 Lab Hours.  Not Listed
# 1631  3 Credit Hours.   0 Lecture Hours.   0 Lab Hours.  Not Listed
#
#         syllabus                   university     term           keyword
# 251   Not Listed  Georgia Southern University  2019-20   polic,technolog
# 560   Not Listed  Georgia Southern University  2019-20  societ,technolog
# 561   Not Listed  Georgia Southern University  2019-20    valu,technolog
# 1092  Not Listed  Georgia Southern University  2018-19   polic,technolog
# 1386  Not Listed  Georgia Southern University  2018-19  societ,technolog
